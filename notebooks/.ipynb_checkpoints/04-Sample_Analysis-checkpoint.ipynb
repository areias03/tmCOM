# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fba_all = pd.read_csv('../data/results/fba_all.csv')
fba_all = fba_all.set_index('Constraints')
fba_all
# Out:
#                      M_Bacteroides_thetaiotaomicron_VPI_5482 + M_Bacteroides_uniformis_ATCC_8492  \
# Constraints
# 33 uM Fe                                                  8.816316e-07
# 0 uM Fe/H                                                -0.000000e+00
# 0,7 uM H; 8,2 uM Fe                                       2.190721e-07
# 2,7 uM H; 33 uM Fe                                        8.816316e-07
# 2,7 uM H                                                  8.719522e-07
# 125 uM Fe                                                 3.339514e-06
# 125 uM H                                                  4.036816e-05
# 125 uM H; 2 mM Fe                                         4.036816e-05
# 125 uM H; 125 uM Fe                                       3.339514e-06
# No constraints                                            2.044708e-04
#
#                      M_Bacteroides_thetaiotaomicron_VPI_5482 + M_Escherichia_coli_ED1a  \
# Constraints
# ...

# %%
x_labels = ['Bt + Bu','Bt + Ec ED1a','Bu + Ec ED1a','Bt + SS']
g = sns.clustermap(fba_all, row_cluster = False, vmin = 0, xticklabels = x_labels)
g.tick_params(axis='both', which='both', length=0)
g.ax_heatmap.set_ylabel(g.ax_heatmap.get_ylabel(), labelpad = 20)
plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)  # For y axis
plt.setp(g.ax_heatmap.get_xticklabels(), rotation=90) # For x axis
plt.savefig('../data/images/ec_fba_all.png', bbox_inches='tight')

# %%
sns.set_theme(style="whitegrid")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=fba_all, kind="bar",
    x="Constraints",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 sns.set_theme(style="whitegrid")
#       3 # Draw a nested barplot by species and sex
# ----> 4 g = sns.catplot(
#       5     data=fba_all, kind="bar", hue="Constraints",
#       6     errorbar="sd", palette="dark", alpha=.6, height=6
#       7 )
#       8 g.despine(left=True)
#       9 g.set_axis_labels("", "Body mass (g)")
#
# File ~/anaconda3/envs/tmcom/lib/python3.9/site-packages/seaborn/categorical.py:2766, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2763     elif x is not None and y is not None:
# ...
