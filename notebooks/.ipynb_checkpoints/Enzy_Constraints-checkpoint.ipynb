# %%
from reframed.io.sbml import load_cbmodel
from cobra.io import read_sbml_model, write_sbml_model
from mewpy.cobra.util import add_enzyme_constraints
from mewpy.simulation import get_simulator
from mewpy.simulation.environment import Environment as Environment
from mewpy.util.request import retreive_gene,retreive_protein,brenda_query,get_smiles
import pandas as pd
import json

# %%
#model = load_cbmodel("../models/non-ec/iAF1260.xml")

# %%
model = read_sbml_model("../models/non-ec/Escherichia_coli_ED1a.xml")

# %%
sim = get_simulator(model)
sim.set_objective("biomass")

# %%
sim.simulate()

# %%
sim.get_gene('ECED1_RS08420')
# Out:
#                                              value
# attribute
# id                                   ECED1_RS08420
# name
# reactions  [6PHBG, 6PHBG2, AB6PGH, AB6PGH2, BGLA1]

# %%
print(sim.genes)
# Out:
# ['585397.9.1830_56.peg', 'ECED1_RS02175', 'ECED1_RS22475', 'WP_000024951.1', 'ECED1_RS25540', 'WP_001116472.1', 'WP_001198717.1', 'ECED1_RS12160', 'WP_000048190.1', 'ECED1_RS19110', 'ECED1_RS23775', 'WP_000963849.1', 'ECED1_RS13850', 'WP_001327408.1', 'ECED1_RS21605', '585397.9.4681.peg', 'ECED1_RS01510', 'ECED1_RS19360', 'WP_000764731.1', 'ECED1_RS06275', '585397.9.657_16.peg', '585397.9.3368.peg', 'ECED1_RS01790', 'ECED1_RS07025', 'ECED1_RS08260', 'ECED1_RS21530', 'ECED1_RS25795', 'WP_000135343.1', 'WP_000737366.1', 'WP_001058819.1', 'WP_001442090.1', 'ECED1_RS25480', 'WP_000815387.1', '585397.9.126_13.peg', '585397.9.4752_11.peg', '585397.9.4753_11.peg', '585397.9.4754_12.peg', '585397.9.4755_13.peg', '585397.9.701_11.peg', '585397.9.702_12.peg', 'ECED1_RS21470', 'WP_000347657.1', 'ECED1_RS14220', 'ECED1_RS22925', 'ECED1_RS01870', 'ECED1_RS10435', 'WP_001069461.1', 'ECED1_RS08465', '585397.9.79.peg', 'ECED1_RS06280', 'ECED1_RS25485', 'ECED1_RS06270', 'ECED1_RS06290', 'ECED1_RS1413
# ...

# %%
ls_gpr_sub = []

for rxn in sim.reactions:
    sub = sim.get_substrates(rxn)
    res = [rxn,sim.get_gpr(rxn),sim.get_substrates(rxn),get_smiles(key for key in sub.keys())]
    print(res)
    ls_gpr_sub.append(res)
    
df_gpr_sub = pd.DataFrame(ls_gpr_sub,columns=[['Reaction', 'GPR', 'Substrates']])
    
df_gpr_sub.head()

# %%
data_all = dict()
try:
    with open(sim.id+".json", 'r') as f:
        data = json.load(f)
except:
    data = dict()
    for gene in sim.genes:
        try:
            info = retreive_gene(gene,"Escherichia coli")
            data[gene]={'protein':info['protein'],'sequence':info['seq'],'ec':[lm[1]for lm in info['properties']['Catalytic Activity']],'mw':info['mw']*0.001,'kcat':brenda_query(user = 'pg45962@uminho.pt',password='Mentafrio+15',ecNumber=ec,organism = 'Escherichia coli')}
            data_all[gene]=info
        except:
            data[gene]={'protein': gene[len(sim._g_prefix):], 'mw': 0}
    with open(sim.id+".json", "w") as f:
        json.dump(data,f)

# %%
print("Genes with missing data:")
for k,v in data.items():
    if v['mw']==0:
        print(k)
# Out:
# Genes with missing data:
# 585397.9.1830_56.peg
# ECED1_RS02175
# ECED1_RS22475
# WP_000024951.1
# ECED1_RS25540
# WP_001116472.1
# WP_001198717.1
# ECED1_RS12160
# WP_000048190.1
# ECED1_RS19110
# ECED1_RS23775
# WP_000963849.1
# ECED1_RS13850
# WP_001327408.1
# ECED1_RS21605
# 585397.9.4681.peg
# ECED1_RS01510
# ECED1_RS19360
# WP_000764731.1
# ECED1_RS06275
# 585397.9.657_16.peg
# 585397.9.3368.peg
# ECED1_RS01790
# ECED1_RS07025
# ECED1_RS08260
# ECED1_RS21530
# ECED1_RS25795
# WP_000135343.1
# WP_000737366.1
# WP_001058819.1
# WP_001442090.1
# ECED1_RS25480
# WP_000815387.1
# 585397.9.126_13.peg
# 585397.9.4752_11.peg
# 585397.9.4753_11.peg
# 585397.9.4754_12.peg
# 585397.9.4755_13.peg
# 585397.9.701_11.peg
# 585397.9.702_12.peg
# ECED1_RS21470
# WP_000347657.1
# ECED1_RS14220
# ECED1_RS22925
# ECED1_RS01870
# ECED1_RS10435
# WP_001069461.1
# ECED1_RS08465
# 585397.9.79.peg
# ECED1_RS06280
# ECED1_RS25485
# ECED1_RS06270
# ECED1_RS06290
# ECED1_RS14130
# ECED1_RS22070
# ...

# %%
df = pd.DataFrame.from_dict(data) 
df = df.transpose()
df = df.iloc[:,0:4]
df
# Out:
#                                    protein mw
# 585397.9.1830_56.peg  585397.9.1830_56.peg  0
# ECED1_RS02175                ECED1_RS02175  0
# ECED1_RS22475                ECED1_RS22475  0
# WP_000024951.1              WP_000024951.1  0
# ECED1_RS25540                ECED1_RS25540  0
# ...                                    ... ..
# ECED1_RS23680                ECED1_RS23680  0
# ECED1_RS23685                ECED1_RS23685  0
# WP_000239730.1              WP_000239730.1  0
# WP_000437380.1              WP_000437380.1  0
# WP_001031057.1              WP_001031057.1  0
#
# [1427 rows x 2 columns]

# %% [markdown]
# ## BRENDA Query

# %%
for ec_l in df[['ec']]:
    for ec in ec_l:
        if ec:
            kcat = brenda_query(user = 'pg45962@uminho.pt',password='Mentafrio+15',ecNumber=ec,organism = 'Escherichia coli')
            if kcat:
                df[['kcat']] = kcat

# %%
#ec_sim = add_enzyme_constraints(sim, data=data)

# %%
#res = ec_sim.simulate()
#print(res)
