# %% [markdown]
# # Enzymatic Constraints Enhancement of AGORA models

# %% [markdown]
# ### Context
#
#
#
# ### Goals:
#
# -

# %%
from tqdm.auto import tqdm
from reframed.io.sbml import load_cbmodel,save_cbmodel
from cobra.io import read_sbml_model, write_sbml_model
from mewpy.cobra.util import add_enzyme_constraints,convert_gpr_to_dnf,split_isozymes
from mewpy.simulation import get_simulator
from mewpy.simulation.environment import Environment as Environment
from mewpy.util.request import retreive_gene,retreive_protein,get_smiles,brenda_query
import pandas as pd
import numpy as np
from urllib.request import urlopen
from functools import reduce
import json
from ast import literal_eval

# %%
filepath = "../models/non-ec/agora/Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586.xml"
model = read_sbml_model(filepath)
model2 = load_cbmodel(filepath)
organism = 'Fusobacterium nucleatum'

# %%
model.id
# Out:
# 'M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586'

# %%
model_id = str(model.id.strip('M_'))
print(model_id)
# Out:
# Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586

# %%
sim = get_simulator(model)
sim.set_objective("biomass")

sim2 = get_simulator(model2)
sim2.set_objective("R_biomass")

# %%
sim.simulate()
# Out:
# objective: 186.53129283071732
# Status: OPTIMAL
# Method:SimulationMethod.FBA

# %%
sim2.simulate()
# Out:
# objective: None
# Status: INF_OR_UNB
# Method:SimulationMethod.FBA

# %% [markdown]
# ## Annotation scraping

# %%
ls_ge = []

for ge in sim.genes:
    i = sim.genes.index(ge)
    gene = sim.genes[i]
    rxns = sim.get_gene(ge).reactions
    for rx in rxns:
        anno = sim.get_reaction(rx)['annotations']
        seed_id = anno.get('seed.reactions')
        rxn_name = sim.get_reaction(rx).name
        ecnumber = anno.get('ec-code')
        metanetx = anno.get('metanetx.reaction')
        kegg = anno.get('kegg.reaction')
        res = [gene,rx,rxn_name,seed_id,metanetx,kegg,ecnumber]
        ls_ge.append(res)

df_ge = pd.DataFrame(ls_ge,columns=[['Gene','Reaction','Name','ModelSEED_id','MetaNetX','KEGG_id','ecNumber']])

df_ge
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 2     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# 3     585397.9.1830_56.peg   2HATVLACGLUC_GLCAASE
# 4     585397.9.1830_56.peg       2HIBUP_S_GLCAASE
# ...                    ...                    ...
# 3645         ECED1_RS23680         rtranscription
# 3646         ECED1_RS23685         rtranscription
# 3647        WP_000239730.1         rtranscription
# 3648        WP_000437380.1         rtranscription
# 3649        WP_001031057.1         rtranscription
#
#                                                    Name ModelSEED_id MetaNetX  \
# 0              1-hydroxy S-ibuprofen beta-glucuronidase         None     None
# 1         1-OH-midazolam-glucuronide beta-glucuronidase         None     None
# 2     2-hydroxy-atorvastatin-acyl-glucuronide beta-g...         None     None
# 3     2-hydroxy-atorvastatin-lactone-glucuronide bet...         None     None
# 4              2-hydroxy-S-ibuprofen beta-glucuronidase         None     None
# ...                                                 ...          ...      ...
# 3645                               RNA transcription c0     rxn13784     None
# 3646                               RNA transcription c0     rxn13784     None
# 3647                               RNA transcription c0     rxn13784     None
# 3648                               RNA transcription c0     rxn13784     None
# 3649                               RNA transcription c0     rxn13784     None
#
#      KEGG_id ecNumber
# 0       None     None
# 1       None     None
# 2       None     None
# 3       None     None
# 4       None     None
# ...      ...      ...
# 3645    None     None
# 3646    None     None
# 3647    None     None
# 3648    None     None
# 3649    None     None
#
# [3650 rows x 7 columns]

# %%
mask = df_ge['ecNumber'].values!=None
ec_nona = df_ge[mask]
ec_nona
# Out:
#                 Gene     Reaction  \
# 170    ECED1_RS02175  1P4H2CBXLAH
# 171    ECED1_RS02175       DHPPDA
# 172    ECED1_RS22475      23DHMPO
# 173    ECED1_RS22475      2AHBUTI
# 174   WP_000024951.1      23DHMPO
# ...              ...          ...
# 3632  WP_000139091.1        r0480
# 3633  WP_000139091.1        r0788
# 3634  WP_000139091.1        r0789
# 3635  WP_000513796.1        r0641
# 3636   ECED1_RS12035        r1384
#
#                                                    Name ModelSEED_id  \
# 170   1-Pyrroline-4-hydroxy-2-carboxylate aminohydro...     rxn01635
# 171   diaminohydroxyphosphoribosylaminopyrimidine de...     rxn02475
# 172   (R)-2,3-Dihydroxy-3-methylpentanoate:NADP+ oxi...     rxn03435
# 173            (S)-2-Aceto-2-hydroxybutanoate isomerase     rxn03436
# 174   (R)-2,3-Dihydroxy-3-methylpentanoate:NADP+ oxi...     rxn03435
# ...                                                 ...          ...
# 3632  S-Adenosyl-L-Methionine:Ethanolamine-Phosphate...     rxn01478
# 3633  S-Adenosyl-L-Methionine:Methylethanolamine Pho...     rxn04681
# 3634  S-Adenosyl-L-Methionine:Phosphodimethylethanol...     rxn04682
# 3635  (5-Glutamyl)-Peptide:Amino-Acid 5-Glutamyltran...     rxn02727
# 3636                           Guanosine Aminohydrolase     rxn01547
#
#         MetaNetX KEGG_id            ecNumber
# 170    MNXR93752    None            3.5.4.22
# 171    MNXR82287    None            3.5.4.26
# 172    MNXR83171    None            1.1.1.86
# 173    MNXR76597    None  1.1.1.86, 5.4.99.3
# 174    MNXR83171    None            1.1.1.86
# ...          ...     ...                 ...
# 3632  MNXR105345  R02037           2.1.1.103
# 3633  MNXR105385  R06868           2.1.1.103
# 3634  MNXR105386  R06869           2.1.1.103
# 3635  MNXR100134    None           3.4.19.14
# 3636  MNXR105466  R02145            3.5.4.15
#
# [2586 rows x 7 columns]

# %%
seed_id = df_ge['ModelSEED_id'].values.tolist()

seed_id = [reduce(lambda x: x, inner_list) for inner_list in seed_id]

metanetx_id = df_ge['MetaNetX'].values.tolist()

metanetx_id = [reduce(lambda x: x, inner_list) for inner_list in metanetx_id]

kegg_id = df_ge['KEGG_id'].values.tolist()

kegg_id = [reduce(lambda x: x, inner_list) for inner_list in kegg_id]

# %% [markdown]
#  ## ModelSEED query

# %%
SOLR_URL='https://modelseed.org'
ls_name = []
ls_kegg = []
ls_bigg = []

for mseed_id in tqdm(seed_id):
    i = seed_id.index(mseed_id)
    if mseed_id == None:
        ls_name.append('None')
        ls_kegg.append('None')
        ls_bigg.append('None')
    else:
        try:
            connection = urlopen(SOLR_URL+f'/solr/reactions/select?wt=json&q=id:{mseed_id}&fl=name,id,formula,charge,aliases')
            response = json.load(connection)
            for document in response['response']['docs']:  
                ms_name = document.get('name')
                ls_alias = document.get('aliases')
                ms_bigg = list(filter(lambda a: 'BiGG:' in a, document.get('aliases')))
                ms_kegg = list(filter(lambda a: 'KEGG:' in a, document.get('aliases')))
                if len(ms_bigg)== 0 and len(ms_kegg)== 0:
                    ms_bigg = 'None'
                    ms_kegg = 'None'
                elif len(ms_bigg)== 0 and len(ms_kegg)!= 0:
                    ms_bigg = 'None'
                    ms_kegg = list(ms_kegg)[0]
                    ms_kegg = ms_kegg.replace('KEGG: ','')
                elif len(ms_bigg)!= 0 and len(ms_kegg)== 0:
                    ms_kegg = 'None'
                    ms_bigg = list(ms_bigg)[0]
                    ms_bigg = ms_bigg.replace('BiGG: ','')
                else:
                    ms_kegg = list(ms_kegg)[0]
                    ms_kegg = ms_kegg.replace('KEGG: ','')
                    ms_bigg = list(ms_bigg)[0]
                    ms_bigg = ms_bigg.replace('BiGG: ','')    
                ls_name.append(ms_name)
                ls_bigg.append(ms_bigg)
                ls_kegg.append(ms_kegg)           
        except:
            ls_name.append('None')
            ls_kegg.append('None')
            ls_bigg.append('None')
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %%
new_kegg = [next(filter(None, i)) for i in zip(ls_kegg, kegg_id)]

# %%
df_ge['BIGG_id'] = ls_bigg
df_ge['KEGG_id'] = new_kegg

# %% [markdown]
# ## BiGG query

# %%
import requests

ls_bigg = df_ge['BIGG_id'].values.tolist()
bigg_ls = []

for bigg in tqdm(ls_bigg):
    for bigg_n in bigg:
        bigg_n = str(bigg_n)
        bigg_n = bigg_n.split(';')
        bigg_n = [x.strip(' ') for x in bigg_n]
        sub_bigg_ls = []
        for bi in bigg_n:
            if bi == 'None':
                pass
            else:
                url =f'http://bigg.ucsd.edu/api/v2/universal/reactions/{bi}'
                with requests.request("GET", url) as resp:
                    try:
                        resp.raise_for_status()  # raises exception when not a 2xx response
                        if resp.status_code != 204:
                            data = dict(resp.json())
                            ec_l = data['database_links']
                            if ec_l == None:
                                sub_bigg_ls.append(None)
                            else:
                                ec = [i['id'] for i in ec_l['EC Number']]
                                if ec == None:
                                    sub_bigg_ls.append(None)
                                sub_bigg_ls.append(ec)
                        else: 
                            sub_bigg_ls.append(None)
                    except:
                        sub_bigg_ls.append(None)
    bigg_ls.append(sub_bigg_ls)
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %%
ec_l = df_ge['ecNumber'].values.tolist()
new_l = [next(filter(None, i)) for i in zip(bigg_ls, ec_l)]
df_ge['ecNumber'] = new_l

# %%
df_ge
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 2     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# 3     585397.9.1830_56.peg   2HATVLACGLUC_GLCAASE
# 4     585397.9.1830_56.peg       2HIBUP_S_GLCAASE
# ...                    ...                    ...
# 3645         ECED1_RS23680         rtranscription
# 3646         ECED1_RS23685         rtranscription
# 3647        WP_000239730.1         rtranscription
# 3648        WP_000437380.1         rtranscription
# 3649        WP_001031057.1         rtranscription
#
#                                                    Name ModelSEED_id MetaNetX  \
# 0              1-hydroxy S-ibuprofen beta-glucuronidase         None     None
# 1         1-OH-midazolam-glucuronide beta-glucuronidase         None     None
# 2     2-hydroxy-atorvastatin-acyl-glucuronide beta-g...         None     None
# 3     2-hydroxy-atorvastatin-lactone-glucuronide bet...         None     None
# 4              2-hydroxy-S-ibuprofen beta-glucuronidase         None     None
# ...                                                 ...          ...      ...
# 3645                               RNA transcription c0     rxn13784     None
# 3646                               RNA transcription c0     rxn13784     None
# 3647                               RNA transcription c0     rxn13784     None
# 3648                               RNA transcription c0     rxn13784     None
# 3649                               RNA transcription c0     rxn13784     None
#
#      KEGG_id ecNumber BIGG_id
# 0       None   [None]    None
# 1       None   [None]    None
# 2       None   [None]    None
# 3       None   [None]    None
# 4       None   [None]    None
# ...      ...      ...     ...
# 3645    None   [None]    None
# 3646    None   [None]    None
# 3647    None   [None]    None
# 3648    None   [None]    None
# 3649    None   [None]    None
#
# [3650 rows x 8 columns]

# %% [markdown]
# ## Substrates

# %%
rx_l = df_ge['Reaction'].values.tolist()
ls_sub = []

for rxn in rx_l:
    for rx in rxn:
        sub = list(sim.get_substrates(rx).keys())
        ls_sub.append(sub)
    
df_ge["Substrates"] = ls_sub   

df_ge
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 2     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# 3     585397.9.1830_56.peg   2HATVLACGLUC_GLCAASE
# 4     585397.9.1830_56.peg       2HIBUP_S_GLCAASE
# ...                    ...                    ...
# 3645         ECED1_RS23680         rtranscription
# 3646         ECED1_RS23685         rtranscription
# 3647        WP_000239730.1         rtranscription
# 3648        WP_000437380.1         rtranscription
# 3649        WP_001031057.1         rtranscription
#
#                                                    Name ModelSEED_id MetaNetX  \
# 0              1-hydroxy S-ibuprofen beta-glucuronidase         None     None
# 1         1-OH-midazolam-glucuronide beta-glucuronidase         None     None
# 2     2-hydroxy-atorvastatin-acyl-glucuronide beta-g...         None     None
# 3     2-hydroxy-atorvastatin-lactone-glucuronide bet...         None     None
# 4              2-hydroxy-S-ibuprofen beta-glucuronidase         None     None
# ...                                                 ...          ...      ...
# 3645                               RNA transcription c0     rxn13784     None
# 3646                               RNA transcription c0     rxn13784     None
# 3647                               RNA transcription c0     rxn13784     None
# 3648                               RNA transcription c0     rxn13784     None
# 3649                               RNA transcription c0     rxn13784     None
#
#      KEGG_id ecNumber BIGG_id                  Substrates
# 0       None   [None]    None    [1hibupglu_S[c], h2o[c]]
# 1       None   [None]    None       [1hmdgluc[c], h2o[c]]
# 2       None   [None]    None  [2hatvacidgluc[c], h2o[c]]
# 3       None   [None]    None   [2hatvlacgluc[c], h2o[c]]
# 4       None   [None]    None    [2hibupglu_S[c], h2o[c]]
# ...      ...      ...     ...                         ...
# 3645    None   [None]    None                          []
# 3646    None   [None]    None                          []
# 3647    None   [None]    None                          []
# 3648    None   [None]    None                          []
# 3649    None   [None]    None                          []
#
# [3650 rows x 9 columns]

# %%
sub_na = df_ge['Substrates'].values.tolist()

ls_sub = []
ls_smile =[]



for sub_l in tqdm(sub_na):
    sub_ls_sub = []
    sub_ls_smile = []
    for sub_s in sub_l:
        for sub in sub_s:
            sub_name = sim.get_metabolite(sub).get('name')
            if "2,3-C" in sub_name:
                sub_name = sub_name.replace("2,3","2',3'")
            elif "2,3-c" in sub_name:
                sub_name = sub_name.replace("2,3","2',3'")
            elif "3-triphosphate" in sub_name:
                sub_name = sub_name.replace("3","3'")
            else:
                pass
            smile = get_smiles(sub_name)
            sub_ls_smile.append(smile)
            sub_ls_sub.append(sub_name)
        ls_sub.append(sub_ls_sub)
        ls_smile.append(sub_ls_smile)

df_ge['Substrate Name'] = ls_sub
df_ge['Substrate SMILES'] = ls_smile
df_ge.to_csv(f'../data/ec_data/ge_data_{model_id}.csv',na_rep='None')
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %%
df_ge = pd.read_csv(f'../data/ec_data/ge_data_{model_id}.csv')
df_ge = df_ge.loc[:,['Gene','Reaction','Name','ModelSEED_id','MetaNetX','KEGG_id','BIGG_id','Substrates','Substrate Name','Substrate SMILES','ecNumber']]
df_ge
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 2     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# 3     585397.9.1830_56.peg   2HATVLACGLUC_GLCAASE
# 4     585397.9.1830_56.peg       2HIBUP_S_GLCAASE
# ...                    ...                    ...
# 3645         ECED1_RS23680         rtranscription
# 3646         ECED1_RS23685         rtranscription
# 3647        WP_000239730.1         rtranscription
# 3648        WP_000437380.1         rtranscription
# 3649        WP_001031057.1         rtranscription
#
#                                                    Name ModelSEED_id MetaNetX  \
# 0              1-hydroxy S-ibuprofen beta-glucuronidase         None     None
# 1         1-OH-midazolam-glucuronide beta-glucuronidase         None     None
# 2     2-hydroxy-atorvastatin-acyl-glucuronide beta-g...         None     None
# 3     2-hydroxy-atorvastatin-lactone-glucuronide bet...         None     None
# 4              2-hydroxy-S-ibuprofen beta-glucuronidase         None     None
# ...                                                 ...          ...      ...
# 3645                               RNA transcription c0     rxn13784     None
# 3646                               RNA transcription c0     rxn13784     None
# 3647                               RNA transcription c0     rxn13784     None
# 3648                               RNA transcription c0     rxn13784     None
# 3649                               RNA transcription c0     rxn13784     None
#
#      KEGG_id BIGG_id                      Substrates  \
# 0       None    None    ['1hibupglu_S[c]', 'h2o[c]']
# 1       None    None       ['1hmdgluc[c]', 'h2o[c]']
# 2       None    None  ['2hatvacidgluc[c]', 'h2o[c]']
# 3       None    None   ['2hatvlacgluc[c]', 'h2o[c]']
# 4       None    None    ['2hibupglu_S[c]', 'h2o[c]']
# ...      ...     ...                             ...
# 3645    None    None                              []
# 3646    None    None                              []
# 3647    None    None                              []
# 3648    None    None                              []
# 3649    None    None                              []
#
#                                          Substrate Name Substrate SMILES  \
# 0        ['1-hydroxy S-ibuprofen-glucuronide', 'Water']      [None, 'O']
# 1               ['1-OH-midazolam-glucuronide', 'Water']      [None, 'O']
# 2     ['2-hydroxy-atorvastatin-acyl-glucuronide', 'W...      [None, 'O']
# 3     ['2-hydroxy-atorvastatin-lactone-glucuronide',...      [None, 'O']
# 4        ['2-hydroxy S-ibuprofen-glucuronide', 'Water']      [None, 'O']
# ...                                                 ...              ...
# 3645                                                 []               []
# 3646                                                 []               []
# 3647                                                 []               []
# 3648                                                 []               []
# 3649                                                 []               []
#
#      ecNumber
# 0      [None]
# 1      [None]
# 2      [None]
# 3      [None]
# 4      [None]
# ...       ...
# 3645   [None]
# 3646   [None]
# 3647   [None]
# 3648   [None]
# 3649   [None]
#
# [3650 rows x 11 columns]

# %%
ec_l = df_ge['ecNumber'].values.tolist()
ec_nl = []
ei = []

for es in ec_l:
    es = str(es)
    es = es.split(',')
    ei = []
    for sublist in es:
        sublist = str(sublist)
        sublist = sublist.strip("[[")
        sublist = sublist.strip(" ")
        sublist = sublist.strip("'")
        sublist = sublist.strip("[")
        sublist = sublist.strip("[")
        sublist = sublist.strip("'")
        sublist = sublist.strip("'")
        sublist = sublist.strip("]")
        sublist = sublist.strip("]]")  
        sublist = sublist.strip("'")
        if sublist not in ei:
            if sublist == 'None' and len(ei) > 0:
                pass
            elif '-' in sublist:
                pass
            else:
                ei.append(sublist)
    ec_nl.append(ei)

df_ge['ecNumber'] = ec_nl

# %% [markdown]
# ## BRENDA query

# %% [markdown]
# ### Kcat extraction

# %%
from brendapyrser import BRENDA
from brendapyrser import EnzymePropertyDict


dataFile = '../../brenda_2023_1.txt'

# %%
brenda = BRENDA(dataFile)
brenda
# Out:
#         <table>
#             <tr>
#                 <td><strong>Number of Enzymes</strong></td><td>7832</td>
#             </tr><tr>
#                 <td><strong>BRENDA copyright</strong></td><td>Copyrighted by Dietmar Schomburg, Techn. University
#         Braunschweig, GERMANY. Distributed under the License as stated
#         at http:/www.brenda-enzymes.org</td>
#             </tr><tr>
#                 <td><strong>Parser version</strong></td><td>0.0.1</td>
#             </tr><tr>
#                 <td><strong>Author</strong></td><td>Semidán Robaina Estévez, 2020</td>
#             </tr>
#         </table>

# %%
kcat_ls = []
ec_ls = df_ge['ecNumber'].values.tolist()

for ec in tqdm(ec_ls):
    ec=str(ec)
    ec = ec.split(',')
    sub_kcat_ls = []
    #print(ec)
    for ec_n in ec:
        ec_n = ec_n.strip(',')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip('[[')
        ec_n = ec_n.strip(']')
        ec_n = ec_n.strip(']]')
        ec_n = ec_n.strip(' ')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip("'")
        ec_n = ec_n.strip(',')
        ec_n = ec_n.strip(' ')
        if "-" in ec_n:
            pass
        elif ec_n == None:
            sub_kcat_ls.append(None)
            continue
        else:
            try:
                r = brenda.reactions.get_by_id(ec_n)
                kcat_va = r.Kcatvalues.get_values()
                avg_kcat = sum(kcat_va)/len(kcat_va)
                sub_kcat_ls.append(avg_kcat)
            except:
                sub_kcat_ls.append(None)
    kcat_ls.append(sub_kcat_ls)

df_ge['Avg Kcat (by ec)'] = kcat_ls
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %%
kcat_ls = []
ec_ls = df_ge['ecNumber'].values.tolist()


for ec in tqdm(ec_ls):
    ec=str(ec)
    ec = ec.split(',')
    sub_kcat_ls = []
    for ec_n in ec:
        ec_n = ec_n.strip(',')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip('[[')
        ec_n = ec_n.strip(']')
        ec_n = ec_n.strip(']]')
        ec_n = ec_n.strip(' ')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip("'")
        if "-" in ec_n:
            pass
        else:
            try:
                r = brenda.reactions.get_by_id(ec_n)
                kcat_va = r.Kcatvalues.filter_by_organism(organism).get_values()
                avg_kcat = sum(kcat_va)/len(kcat_va)
                sub_kcat_ls.append(avg_kcat)
            except:
                sub_kcat_ls.append(None)
    kcat_ls.append(sub_kcat_ls)

df_ge['Avg Kcat (by ec and species)'] = kcat_ls
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %% [markdown]
# ### Sequence extraction

# %%
seq_ls = []
ec_ls = df_ge['ecNumber'].values.tolist()


for ec in tqdm(ec_ls):
    ec=str(ec)
    ec = ec.split(',')
    sub_seq_ls = []
    for ec_n in ec:
        ec_n = ec_n.strip(',')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip('[[')
        ec_n = ec_n.strip(']')
        ec_n = ec_n.strip(']]')
        ec_n = ec_n.strip(' ')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip("'")
        ec_n = ec_n.strip(' ')
        ec_n = ec_n.strip('[')
        if "-" in ec_n:
            pass
        elif ec_n == None:
            sub_mw_ls.append(None)
            continue
        else:
            try:
                from zeep import Client
                import hashlib

                wsdl = "https://www.brenda-enzymes.org/soap/brenda_zeep.wsdl"
                password = hashlib.sha256("07042000Alex!".encode("utf-8")).hexdigest()
                client = Client(wsdl)
                parameters = ( "alexandreareias1718@gmail.com",password,f"ecNumber*{ec_n}","sequence*", "noOfAminoAcids*", "firstAccessionCode*", "source*", "id*", f"organism*{organism}")
                resultString = client.service.getSequence(*parameters) 
                sub_seq_ls.append(resultString[0]['sequence'])
            except:
                sub_seq_ls.append(None)                  
    seq_ls.append(sub_seq_ls)
    
df_ge['Protein Sequence'] = seq_ls
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %% [markdown]
# ### Molecular Weight extraction

# %%
mw_ls = []
ec_ls = df_ge['ecNumber'].values.tolist()


for ec in tqdm(ec_ls):
    ec=str(ec)
    ec = ec.split(',')
    sub_mw_ls = []
    for ec_n in ec:
        ec_n = ec_n.strip(',')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip('[[')
        ec_n = ec_n.strip(']')
        ec_n = ec_n.strip(']]')
        ec_n = ec_n.strip(' ')
        ec_n = ec_n.strip('[')
        ec_n = ec_n.strip("'")
        ec_n = ec_n.strip(' ')
        ec_n = ec_n.strip('[')
        if "-" in ec_n:
            pass
        elif ec_n == None:
            sub_mw_ls.append(None)
            continue
        else:
            try:
                from zeep import Client
                import hashlib
                
                res_mw = 0
                wsdl = "https://www.brenda-enzymes.org/soap/brenda_zeep.wsdl"
                password = hashlib.sha256("07042000Alex!".encode("utf-8")).hexdigest()
                client = Client(wsdl)
                parameters = ("alexandreareias1718@gmail.com",password,f"ecNumber*{ec_n}","molecularWeight*","molecularWeightMaximum*","commentary*",f"organism*{organism}","literature*" )
                resultString = client.service.getMolecularWeight(*parameters)
                for i in range(len(resultString)):
                    res_mw = res_mw + int(resultString[i]['molecularWeight'])
                res_mw = res_mw/len(resultString)
                sub_mw_ls.append(res_mw)
            except:
                sub_mw_ls.append(None)                  
    mw_ls.append(sub_mw_ls)

df_ge['Molecular Weight'] = mw_ls
# Out:
#   0%|          | 0/3650 [00:00<?, ?it/s]

# %%
from zeep import Client
import hashlib

res_mw = 0

wsdl = "https://www.brenda-enzymes.org/soap/brenda_zeep.wsdl"
password = hashlib.sha256("07042000Alex!".encode("utf-8")).hexdigest()
client = Client(wsdl)
parameters = ("alexandreareias1718@gmail.com",password,"ecNumber*1.1.1.86", "molecularWeight*", "molecularWeightMaximum*", "commentary*", f"organism*{organism}", "literature*")
resultString = client.service.getMolecularWeight(*parameters) 
for i in range(len(resultString)):
        res_mw = res_mw + int(resultString[i]['molecularWeight'])
res_mw = res_mw/len(resultString)
print(res_mw)
# Out:
# 141357.0

# %%
df_ge
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 2     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# 3     585397.9.1830_56.peg   2HATVLACGLUC_GLCAASE
# 4     585397.9.1830_56.peg       2HIBUP_S_GLCAASE
# ...                    ...                    ...
# 3645         ECED1_RS23680         rtranscription
# 3646         ECED1_RS23685         rtranscription
# 3647        WP_000239730.1         rtranscription
# 3648        WP_000437380.1         rtranscription
# 3649        WP_001031057.1         rtranscription
#
#                                                    Name ModelSEED_id MetaNetX  \
# 0              1-hydroxy S-ibuprofen beta-glucuronidase         None     None
# 1         1-OH-midazolam-glucuronide beta-glucuronidase         None     None
# 2     2-hydroxy-atorvastatin-acyl-glucuronide beta-g...         None     None
# 3     2-hydroxy-atorvastatin-lactone-glucuronide bet...         None     None
# 4              2-hydroxy-S-ibuprofen beta-glucuronidase         None     None
# ...                                                 ...          ...      ...
# 3645                               RNA transcription c0     rxn13784     None
# 3646                               RNA transcription c0     rxn13784     None
# 3647                               RNA transcription c0     rxn13784     None
# 3648                               RNA transcription c0     rxn13784     None
# 3649                               RNA transcription c0     rxn13784     None
#
#      KEGG_id BIGG_id                      Substrates  \
# 0       None    None    ['1hibupglu_S[c]', 'h2o[c]']
# 1       None    None       ['1hmdgluc[c]', 'h2o[c]']
# 2       None    None  ['2hatvacidgluc[c]', 'h2o[c]']
# 3       None    None   ['2hatvlacgluc[c]', 'h2o[c]']
# 4       None    None    ['2hibupglu_S[c]', 'h2o[c]']
# ...      ...     ...                             ...
# 3645    None    None                              []
# 3646    None    None                              []
# 3647    None    None                              []
# 3648    None    None                              []
# 3649    None    None                              []
#
#                                          Substrate Name Substrate SMILES  \
# 0        ['1-hydroxy S-ibuprofen-glucuronide', 'Water']      [None, 'O']
# 1               ['1-OH-midazolam-glucuronide', 'Water']      [None, 'O']
# 2     ['2-hydroxy-atorvastatin-acyl-glucuronide', 'W...      [None, 'O']
# 3     ['2-hydroxy-atorvastatin-lactone-glucuronide',...      [None, 'O']
# 4        ['2-hydroxy S-ibuprofen-glucuronide', 'Water']      [None, 'O']
# ...                                                 ...              ...
# 3645                                                 []               []
# 3646                                                 []               []
# 3647                                                 []               []
# 3648                                                 []               []
# 3649                                                 []               []
#
#      ecNumber Avg Kcat (by ec) Avg Kcat (by ec and species) Protein Sequence  \
# 0      [None]           [None]                       [None]           [None]
# 1      [None]           [None]                       [None]           [None]
# 2      [None]           [None]                       [None]           [None]
# 3      [None]           [None]                       [None]           [None]
# 4      [None]           [None]                       [None]           [None]
# ...       ...              ...                          ...              ...
# 3645   [None]           [None]                       [None]           [None]
# 3646   [None]           [None]                       [None]           [None]
# 3647   [None]           [None]                       [None]           [None]
# 3648   [None]           [None]                       [None]           [None]
# 3649   [None]           [None]                       [None]           [None]
#
#      Molecular Weight
# 0              [None]
# 1              [None]
# 2              [None]
# 3              [None]
# 4              [None]
# ...               ...
# 3645           [None]
# 3646           [None]
# 3647           [None]
# 3648           [None]
# 3649           [None]
#
# [3650 rows x 15 columns]

# %% [markdown]
# ## DLKcat - Kcat prediction

# %%
dk_prep = df_ge.drop(columns=['Substrates','ModelSEED_id','MetaNetX','KEGG_id','BIGG_id','ecNumber'])
dk_prep
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 2     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# 3     585397.9.1830_56.peg   2HATVLACGLUC_GLCAASE
# 4     585397.9.1830_56.peg       2HIBUP_S_GLCAASE
# ...                    ...                    ...
# 3645         ECED1_RS23680         rtranscription
# 3646         ECED1_RS23685         rtranscription
# 3647        WP_000239730.1         rtranscription
# 3648        WP_000437380.1         rtranscription
# 3649        WP_001031057.1         rtranscription
#
#                                                    Name  \
# 0              1-hydroxy S-ibuprofen beta-glucuronidase
# 1         1-OH-midazolam-glucuronide beta-glucuronidase
# 2     2-hydroxy-atorvastatin-acyl-glucuronide beta-g...
# 3     2-hydroxy-atorvastatin-lactone-glucuronide bet...
# 4              2-hydroxy-S-ibuprofen beta-glucuronidase
# ...                                                 ...
# 3645                               RNA transcription c0
# 3646                               RNA transcription c0
# 3647                               RNA transcription c0
# 3648                               RNA transcription c0
# 3649                               RNA transcription c0
#
#                                          Substrate Name Substrate SMILES  \
# 0        ['1-hydroxy S-ibuprofen-glucuronide', 'Water']      [None, 'O']
# 1               ['1-OH-midazolam-glucuronide', 'Water']      [None, 'O']
# 2     ['2-hydroxy-atorvastatin-acyl-glucuronide', 'W...      [None, 'O']
# 3     ['2-hydroxy-atorvastatin-lactone-glucuronide',...      [None, 'O']
# 4        ['2-hydroxy S-ibuprofen-glucuronide', 'Water']      [None, 'O']
# ...                                                 ...              ...
# 3645                                                 []               []
# 3646                                                 []               []
# 3647                                                 []               []
# 3648                                                 []               []
# 3649                                                 []               []
#
#      Avg Kcat (by ec) Avg Kcat (by ec and species) Protein Sequence  \
# 0              [None]                       [None]           [None]
# 1              [None]                       [None]           [None]
# 2              [None]                       [None]           [None]
# 3              [None]                       [None]           [None]
# 4              [None]                       [None]           [None]
# ...               ...                          ...              ...
# 3645           [None]                       [None]           [None]
# 3646           [None]                       [None]           [None]
# 3647           [None]                       [None]           [None]
# 3648           [None]                       [None]           [None]
# 3649           [None]                       [None]           [None]
#
#      Molecular Weight
# 0              [None]
# 1              [None]
# 2              [None]
# 3              [None]
# 4              [None]
# ...               ...
# 3645           [None]
# 3646           [None]
# 3647           [None]
# 3648           [None]
# 3649           [None]
#
# [3650 rows x 9 columns]

# %%
dk_prep['Substrate Name'] = dk_prep['Substrate Name'].apply(literal_eval) #convert to list type
dk_prep['Substrate SMILES'] = dk_prep['Substrate SMILES'].apply(literal_eval) #convert to list type
dk_prep = dk_prep.explode(['Substrate Name','Substrate SMILES']).reset_index(drop=True)

# %%
#dk_prep['Protein Sequence'] = dk_prep['Protein Sequence'].apply(literal_eval) #convert to list type
#dk_prep['Molecular Weight'] = dk_prep['Molecular Weight'].apply(literal_eval) #convert to list type
dk_prep = dk_prep.explode(['Protein Sequence','Molecular Weight','Avg Kcat (by ec)','Avg Kcat (by ec and species)']).reset_index(drop=True)

# %%
dk_inp = dk_prep.drop(columns=['Gene','Reaction', 'Name', 'Avg Kcat (by ec)', 'Avg Kcat (by ec and species)','Molecular Weight'])
dk_inp.to_csv(f'../../DLKcat/DeeplearningApproach/Code/example/dk_input_{model_id}.tsv',sep="\t",na_rep='None',index= False)

# %%
dk_inp
# Out:
#                                Substrate Name Substrate SMILES  \
# 0           1-hydroxy S-ibuprofen-glucuronide             None
# 1                                       Water                O
# 2                  1-OH-midazolam-glucuronide             None
# 3                                       Water                O
# 4     2-hydroxy-atorvastatin-acyl-glucuronide             None
# ...                                       ...              ...
# 9833                                      NaN              NaN
# 9834                                      NaN              NaN
# 9835                                      NaN              NaN
# 9836                                      NaN              NaN
# 9837                                      NaN              NaN
#
#      Protein Sequence
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# ...               ...
# 9833              NaN
# 9834              NaN
# 9835              NaN
# 9836              NaN
# 9837              NaN
#
# [9838 rows x 3 columns]

# %% [markdown]
# Run DLKcat

# %%
dk_out = pd.read_csv(f'../../DLKcat/DeeplearningApproach/Code/example/output.tsv', sep="\t")
dk_out['Gene'] = dk_prep['Gene']
dk_out['Reaction'] = dk_prep['Reaction']
dk_out['Molecular Weight'] = dk_prep['Molecular Weight']
dk_out['Avg Kcat (by ec)'] = dk_prep['Avg Kcat (by ec)']
dk_out = dk_out.loc[:,['Gene','Reaction','Substrate Name','Substrate SMILES','Protein Sequence','Molecular Weight','Kcat value (1/s)','Avg Kcat (by ec)']]  
dk_out
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 2     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 3     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 4     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# ...                    ...                    ...
# 9833         ECED1_RS23680         rtranscription
# 9834         ECED1_RS23685         rtranscription
# 9835        WP_000239730.1         rtranscription
# 9836        WP_000437380.1         rtranscription
# 9837        WP_001031057.1         rtranscription
#
#                                Substrate Name Substrate SMILES  \
# 0           1-hydroxy S-ibuprofen-glucuronide             None
# 1                                       Water                O
# 2                  1-OH-midazolam-glucuronide             None
# 3                                       Water                O
# 4     2-hydroxy-atorvastatin-acyl-glucuronide             None
# ...                                       ...              ...
# 9833                                     None             None
# 9834                                     None             None
# 9835                                     None             None
# 9836                                     None             None
# 9837                                     None             None
#
#      Protein Sequence Molecular Weight Kcat value (1/s) Avg Kcat (by ec)
# 0                None             None             None             None
# 1                None             None           0.8537             None
# 2                None             None             None             None
# 3                None             None           0.8537             None
# 4                None             None             None             None
# ...               ...              ...              ...              ...
# 9833             None             None             None             None
# 9834             None             None             None             None
# 9835             None             None             None             None
# 9836             None             None             None             None
# 9837             None             None             None             None
#
# [9838 rows x 8 columns]

# %% [markdown]
# ### Joining Kcat values

# %%
kcat_brenda = dk_out['Avg Kcat (by ec)'].values.tolist()
kcat_dl = dk_out['Kcat value (1/s)'].values.tolist()
new_kcat = []

for i in range(len(kcat_brenda)):
    if kcat_brenda[i] != None and kcat_dl[i] != 'None':
        kcat = (float(kcat_brenda[i]) + float(kcat_dl[i]))/2
    elif kcat_brenda[i] == None and kcat_dl[i] != 'None':
        kcat = kcat_dl[i]
    elif kcat_brenda[i] != None and kcat_dl[i] == 'None':
        kcat = kcat_brenda[i]
    elif kcat_brenda[i] == None and kcat_dl[i] == 'None':
        kcat = 0
    new_kcat.append(kcat)
    
dk_out['New Kcat'] = new_kcat
dk_out
# Out:
#                       Gene               Reaction  \
# 0     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 1     585397.9.1830_56.peg       1HIBUP_S_GLCAASE
# 2     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 3     585397.9.1830_56.peg       1HMDGLUC_GLCAASE
# 4     585397.9.1830_56.peg  2HATVACIDGLUC_GLCAASE
# ...                    ...                    ...
# 9833         ECED1_RS23680         rtranscription
# 9834         ECED1_RS23685         rtranscription
# 9835        WP_000239730.1         rtranscription
# 9836        WP_000437380.1         rtranscription
# 9837        WP_001031057.1         rtranscription
#
#                                Substrate Name Substrate SMILES  \
# 0           1-hydroxy S-ibuprofen-glucuronide             None
# 1                                       Water                O
# 2                  1-OH-midazolam-glucuronide             None
# 3                                       Water                O
# 4     2-hydroxy-atorvastatin-acyl-glucuronide             None
# ...                                       ...              ...
# 9833                                     None             None
# 9834                                     None             None
# 9835                                     None             None
# 9836                                     None             None
# 9837                                     None             None
#
#      Protein Sequence Molecular Weight Kcat value (1/s) Avg Kcat (by ec)  \
# 0                None             None             None             None
# 1                None             None           0.8537             None
# 2                None             None             None             None
# 3                None             None           0.8537             None
# 4                None             None             None             None
# ...               ...              ...              ...              ...
# 9833             None             None             None             None
# 9834             None             None             None             None
# 9835             None             None             None             None
# 9836             None             None             None             None
# 9837             None             None             None             None
#
#      New Kcat
# 0           0
# 1      0.8537
# 2           0
# 3      0.8537
# 4           0
# ...       ...
# 9833        0
# 9834        0
# 9835        0
# 9836        0
# 9837        0
#
# [9838 rows x 9 columns]

# %% [markdown]
# ## Adding ezymatic constraints

# %%
genes = dk_out['Gene'].values.tolist()
mweights = dk_out['Molecular Weight'].values.tolist()
kcats = dk_out['New Kcat'].values.tolist()

ec_data = dict()
for gene in genes:
    ge = sim.get_gene(gene).id
    i = genes.index(gene)
    mw = mweights[i]
    if mw == None:
        mw = 0
    kcat = kcats[i]
    if kcat == None:
        kcat = 1
    ec_data[ge]={'protein':ge[len(sim._g_prefix):],'mw':mw,'kcat':kcat}
    
print(ec_data)
with open(f"../data/ec_data/{model_id}.json", "w") as f:
    json.dump(ec_data,f)
# Out:
# {'585397.9.1830_56.peg': {'protein': '585397.9.1830_56.peg', 'mw': 0, 'kcat': 0}, 'ECED1_RS02175': {'protein': 'ECED1_RS02175', 'mw': 0, 'kcat': 32.4219}, 'ECED1_RS22475': {'protein': 'ECED1_RS22475', 'mw': 141357.0, 'kcat': 3.222513120068027}, 'WP_000024951.1': {'protein': 'WP_000024951.1', 'mw': 141357.0, 'kcat': 3.222513120068027}, 'ECED1_RS25540': {'protein': 'ECED1_RS25540', 'mw': 0, 'kcat': 5.361464705882353}, 'WP_001116472.1': {'protein': 'WP_001116472.1', 'mw': 0, 'kcat': '5.4670'}, 'WP_001198717.1': {'protein': 'WP_001198717.1', 'mw': 0, 'kcat': '5.4670'}, 'ECED1_RS12160': {'protein': 'ECED1_RS12160', 'mw': 0, 'kcat': '5.4670'}, 'WP_000048190.1': {'protein': 'WP_000048190.1', 'mw': 0, 'kcat': '5.4670'}, 'ECED1_RS19110': {'protein': 'ECED1_RS19110', 'mw': 0, 'kcat': 60.425050000000006}, 'ECED1_RS23775': {'protein': 'ECED1_RS23775', 'mw': 0, 'kcat': '27.2297'}, 'WP_000963849.1': {'protein': 'WP_000963849.1', 'mw': 0, 'kcat': 0}, 'ECED1_RS13850': {'protein': 'ECED1_RS13850', 'mw': 0, 'kcat': '0.0464'}, 'WP_001327408.1': {'protein': 'WP_001327408.1', 'mw': 0, 'kcat': '0.8537'}, 'ECED1_RS21605': {'protein': 'ECED1_RS21605', 'mw': 0, 'kcat': 237.34283644086028}, '585397.9.4681.peg': {'protein': '585397.9.4681.peg', 'mw': 0, 'kcat': '1.1192'}, 'ECED1_RS01510': {'protein': 'ECED1_RS01510', 'mw': 0, 'kcat': '1091.5851'}, 'ECED1_RS19360': {'protein': 'ECED1_RS19360', 'mw': 0, 'kcat': '3.1562'}, 'WP_000764731.1': {'protein': 'WP_000764731.1', 'mw': 0, 'kcat': '3.1562'}, 'ECED1_RS06275': {'protein': 'ECED1_RS06275', 'mw': 41851.25, 'kcat': 6.282991666666667}, '585397.9.657_16.peg': {'protein': '585397.9.657_16.peg', 'mw': 0, 'kcat': '0.5259'}, '585397.9.3368.peg': {'protein': '585397.9.3368.peg', 'mw': 0, 'kcat': '0.1048'}, 'ECED1_RS01790': {'protein': 'ECED1_RS01790', 'mw': 0, 'kcat': 28.0073057885305}, 'ECED1_RS07025': {'protein': 'ECED1_RS07025', 'mw': 0, 'kcat': 27.603905788530497}, 'ECED1_RS08260': {'protein': 'ECED1_RS08260', 'mw': 0, 'kcat': 27.603905788530497}, 'ECED1_RS21530': {'protein': 'ECED1_RS21530', 'mw': 0, 'kcat': 28.0073057885305}, 'ECED1_RS25795': {'protein': 'ECED1_RS25795', 'mw': 0, 'kcat': 28.0073057885305}, 'WP_000135343.1': {'protein': 'WP_000135343.1', 'mw': 0, 'kcat': 27.603905788530497}, 'WP_000737366.1': {'protein': 'WP_000737366.1', 'mw': 0, 'kcat': 27.603905788530497}, 'WP_001058819.1': {'protein': 'WP_001058819.1', 'mw': 0, 'kcat': 27.603905788530497}, 'WP_001442090.1': {'protein': 'WP_001442090.1', 'mw': 0, 'kcat': 28.0073057885305}, 'ECED1_RS25480': {'protein': 'ECED1_RS25480', 'mw': 0, 'kcat': 43.53256304347826}, 'WP_000815387.1': {'protein': 'WP_000815387.1', 'mw': 0, 'kcat': '4.1357'}, '585397.9.126_13.peg': {'protein': '585397.9.126_13.peg', 'mw': 157402.5, 'kcat': 4.371332692307693}, '585397.9.4752_11.peg': {'protein': '585397.9.4752_11.peg', 'mw': 157402.5, 'kcat': 4.688582692307693}, '585397.9.4753_11.peg': {'protein': '585397.9.4753_11.peg', 'mw': 157402.5, 'kcat': 4.371332692307693}, '585397.9.4754_12.peg': {'protein': '585397.9.4754_12.peg', 'mw': 157402.5, 'kcat': 4.371332692307693}, '585397.9.4755_13.peg': {'protein': '585397.9.4755_13.peg', 'mw': 157402.5, 'kcat': 4.371332692307693}, '585397.9.701_11.peg': {'protein': '585397.9.701_11.peg', 'mw': 157402.5, 'kcat': 4.371332692307693}, '585397.9.702_12.peg': {'protein': '585397.9.702_12.peg', 'mw': 157402.5, 'kcat': 4.371332692307693}, 'ECED1_RS21470': {'protein': 'ECED1_RS21470', 'mw': 0, 'kcat': '5.0675'}, 'WP_000347657.1': {'protein': 'WP_000347657.1', 'mw': 0, 'kcat': '25.9227'}, 'ECED1_RS14220': {'protein': 'ECED1_RS14220', 'mw': 0, 'kcat': '3.7945'}, 'ECED1_RS22925': {'protein': 'ECED1_RS22925', 'mw': 0, 'kcat': '3.7945'}, 'ECED1_RS01870': {'protein': 'ECED1_RS01870', 'mw': 0, 'kcat': '7.8714'}, 'ECED1_RS10435': {'protein': 'ECED1_RS10435', 'mw': 0, 'kcat': '3.1540'}, 'WP_001069461.1': {'protein': 'WP_001069461.1', 'mw': 0, 'kcat': '3.1540'}, 'ECED1_RS08465': {'protein': 'ECED1_RS08465', 'mw': 0, 'kcat': 3.731833333333334}, '58539 ...

# %%
with open(f"../data/ec_data/{model_id}.json") as json_file:
    ec_data = json.load(json_file)

# %%
print("Genes with missing data:")
for k,v in ec_data.items():
    if v['mw']==0:
        print(k)
# Out:
# Genes with missing data:
# g.191.peg.13
# 190304.8.242.peg
# g.191.peg.1069
# g.191.peg.177
# g.191.peg.1752
# g.191.peg.561
# g.191.peg.1073
# g.191.peg.1079
# g.191.peg.688
# g.191.peg.846
# g.191.peg.70
# g.191.peg.1104
# g.191.peg.1715
# g.191.peg.704
# g.191.peg.1644
# g.191.peg.1851
# g.191.peg.418
# g.191.peg.1730
# g.191.peg.546
# 190304.8.218.peg
# 190304.8.219_22.peg
# 190304.8.1540.peg
# 190304.8.220_21.peg
# 190304.8.1542.peg
# 190304.8.532.peg
# 190304.8.1863_17.peg
# g.191.peg.186
# g.191.peg.1889
# g.191.peg.552
# 190304.8.1475_37.peg
# g.191.peg.1396
# 190304.8.97.peg
# g.191.peg.1899
# 190304.8.1547_12.peg
# g.191.peg.1003
# g.191.peg.1224
# g.191.peg.1335
# g.191.peg.342
# g.191.peg.390
# g.191.peg.1297
# g.191.peg.397
# g.191.peg.1445
# g.191.peg.1168
# 190304.8.1567.peg
# 190304.8.46.peg
# 190304.8.247_16.peg
# 190304.8.799_2.peg
# g.191.peg.1424
# 190304.8.11_2_5.peg
# g.191.peg.112
# g.191.peg.728
# 190304.8.1339.peg
# 190304.8.996_5.peg
# 190304.8.1979.peg
# 190304.8.912.peg
# 190304.8.1786.peg
# 190304.8.356.peg
# g.191.peg.1792
# g.191.peg.1004
# g.191.peg.247
# 190304.8.637_10.peg
# 190304.8.1498.peg
# g.191.peg.1762
# g.191.peg.468
# 190304.8.1516_9_24.peg
# 190304.8.1517_9.peg
# 190304.8.1522_9.peg
# 190304.8.1532_13.peg
# 190304.8.1531_21.peg
# 190304.8.1515_15.peg
# 190304.8.1535_24.peg
# g.191.peg.636
# 190304.8.1868_31.peg
# 190304.8.264_31.peg
# 190304.8.677_31.peg
# 190304.8.1537_27.peg
# g.191.peg.1166
# 190304.8.1620_5.peg
# 190304.8.1783_5.peg
# g.191.peg.768
# g.191.peg.874
# 190304.8.235_18.peg
# g.191.peg.1101
# g.191.peg.2016
# 190304.8.337_22.peg
# 190304.8.1566.peg
# g.191.peg.1082
# g.191.peg.1063
# g.191.peg.1585
# g.191.peg.372
# g.191.peg.482
# g.191.peg.1064
# g.191.peg.1146
# g.191.peg.1760
# 190304.8.822_12.peg
# 190304.8.1579_11_19.peg
# 190304.8.45.peg
# 190304.8.664_7.peg
# 190304.8.1000_10.peg
# 190304.8.1001_11.peg
# 190304.8.997_6.peg
# g.191.peg.1438
# g.191.peg.1853
# g.191.peg.318
# g.191.peg.1626
# g.191.peg.599
# g.191.peg.517
# g.191.peg.1137
# 190304.8.407_12.peg
# g.191.peg.691
# g.191.peg.325
# g.191.peg.1058
# g.191.peg.193
# 190304.8.243.peg
# g.191.peg.415
# g.191.peg.815
# g.191.peg.1672
# g.191.peg.51
# g.191.peg.885
# g.191.peg.37
# g.191.peg.1060
# g.191.peg.1429
# g.191.peg.1474
# g.191.peg.759
# 190304.8.252_3.peg
# g.191.peg.1391
# g.191.peg.1834
# 190304.8.902_4.peg
# g.191.peg.1180
# 190304.8.1360_9.peg
# 190304.8.1724_10.peg
# g.191.peg.64
# g.191.peg.797
# g.191.peg.1067
# 190304.8.1270_19_17.peg
# 190304.8.665.peg
# g.191.peg.936
# g.191.peg.497
# g.191.peg.1603
# g.191.peg.2038
# g.191.peg.661
# g.191.peg.1478
# g.191.peg.334
# g.191.peg.1716
# g.191.peg.233
# g.191.peg.510
# g.191.peg.1536
# 190304.8.1024_12.peg
# 190304.8.1550_3.peg
# g.191.peg.659
# 190304.8.1058_6.peg
# 190304.8.1552.peg
# 190304.8.1726.peg
# g.191.peg.1803
# g.191.peg.470
# 190304.8.1794_17.peg
# g.191.peg.1029
# g.191.peg.1209
# g.191.peg.1658
# 190304.8.663_1.peg
# g.191.peg.1323
# g.191.peg.142
# g.191.peg.1515
# g.191.peg.253
# g.191.peg.367
# g.191.peg.908
# g.191.peg.277
# g.191.peg.543
# g.191.peg.780
# g.191.peg.1412
# g.191.peg.43
# 190304.8.2003_19.peg
# g.191.peg.1301
# g.191.peg.547
# g.191.peg.964
# g.191.peg.781
# g.191.peg.1367
# g.191.peg.2041
# g.191.peg.39
# g.191.peg.697
# g.191.peg.1435
# g.191.peg.1090
# 190304.8.234.peg
# g.191.peg.1885
# g.191.peg.477
# g.191.peg.1573
# g.191.peg.1686
# g.191.peg.786
# g.191.peg.1051
# 190304.8.1765.peg
# g.191.peg.1302
# g.191.peg.491
# g.191.peg.376
# 190304.8.1697.peg
# g.191.peg.424
# 190304.8.602.peg
# g.191.peg.143
# g.191.peg.1631
# g.191.peg.18
# g.191.peg.1260
# g.191.peg.1827
# 190304.8.1003_14.peg
# 190304.8.1004_13.peg
# g.191.peg.513
# g.191.peg.567
# g.191.peg.396
# 190304.8.1292_33.peg
# g.191.peg.1248
# g.191.peg.1592
# g.191.peg.1937
# g.191.peg.750
# 190304.8.1274.peg
# g.191.peg.635
# 190304.8.1546.peg
# 190304.8.1555_5_6.peg
# 190304.8.1551_8.peg
# 190304.8.1553_10.peg
# 190304.8.1497.peg
# 190304.8.253_36.peg
# 190304.8.1245_38.peg
# 190304.8.10_8.peg
# g.191.peg.1200
# g.191.peg.1927
# g.191.peg.499
# 190304.8.244_11.peg
# 190304.8.245_11.peg
# 190304.8.246_4.peg
# g.191.peg.1934
# 190304.8.1383_1.peg
# g.191.peg.941
# g.191.peg.1733
# 190304.8.1372.peg
# 190304.8.1972_2.peg
# g.191.peg.1284
# g.191.peg.1509
# g.191.peg.1530
# g.191.peg.1748
# g.191.peg.1775
# g.191.peg.530
# 190304.8.241_3.peg
# g.191.peg.970
# 190304.8.821_20.peg
# g.191.peg.1970
# 190304.8.248_5.peg
# g.191.peg.361
# g.191.peg.1769
# g.191.peg.1780
# g.191.peg.1953
# g.191.peg.2048
# g.191.peg.60
# g.191.peg.971
# g.191.peg.1633
# g.191.peg.1524
# g.191.peg.1881
# g.191.peg.1651
# g.191.peg.1185
# g.191.peg.1327
# g.191.peg.204
# g.191.peg.1080
# g.191.peg.2050
# g.191.peg.911
# 190304.8.46_13.peg
# g.191.peg.1322
# g.191.peg.1343
# g.191.peg.152
# g.191.peg.24
# g.191.peg.719
# g.191.peg.761
# g.191.peg.1132
# g.191.peg.1283
# g.191.peg.150
# g.191.peg.157
# g.191.peg.1765
# g.191.peg.1798
# g.191.peg.1835
# g.191.peg.1928
# g.191.peg.207
# g.191.peg.278
# g.191.peg.333
# g.191.peg.36
# g.191.peg.461
# g.191.peg.675
# g.191.peg.787
# g.191.peg.882
# g.191.peg.987
# g.191.peg.1006
# g.191.peg.1020
# g.191.peg.1083
# g.191.peg.1107
# g.191.peg.1159
# g.191.peg.1165
# g.191.peg.117
# g.191.peg.1205
# g.191.peg.1212
# g.191.peg.1217
# g.191.peg.122
# g.191.peg.1228
# g.191.peg.1251
# g.191.peg.1292
# g.191.peg.1305
# g.191.peg.1337
# g.191.peg.1340
# g.191.peg.1366
# g.191.peg.1456
# g.191.peg.147
# g.191.peg.1472
# g.191.peg.1494
# g.191.peg.1531
# g.191.peg.1547
# g.191.peg.1571
# g.191.peg.1599
# g.191.peg.1628
# g.191.peg.1639
# g.191.peg.166
# g.191.peg.1729
# g.191.peg.1787
# g.191.peg.1862
# g.191.peg.1866
# g.191.peg.1964
# g.191.peg.1974
# g.191.peg.2002
# g.191.peg.206
# g.191.peg.257
# g.191.peg.267
# g.191.peg.296
# g.191.peg.309
# g.191.peg.352
# g.191.peg.353
# g.191.peg.368
# g.191.peg.398
# g.191.peg.401
# g.191.peg.50
# g.191.peg.504
# g.191.peg.528
# g.191.peg.55
# g.191.peg.559
# g.191.peg.6
# g.191.peg.600
# g.191.peg.612
# g.191.peg.624
# g.191.peg.627
# g.191.peg.639
# g.191.peg.656
# g.191.peg.693
# g.191.peg.714
# g.191.peg.740
# g.191.peg.764
# g.191.peg.784
# g.191.peg.79
# g.191.peg.849
# g.191.peg.86
# g.191.peg.865
# g.191.peg.886
# g.191.peg.895
# g.191.peg.903
# g.191.peg.93
# g.191.peg.979
# g.191.peg.997
# g.191.peg.574
# g.191.peg.1406
# 190304.8.1314_16.peg
# g.191.peg.1242
# g.191.peg.1365
# g.191.peg.1382
# g.191.peg.1408
# g.191.peg.1442
# g.191.peg.189
# g.191.peg.1933
# g.191.peg.1947
# g.191.peg.203
# g.191.peg.615
# g.191.peg.957

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from tmcom.util import add_enzyme_constraints

ec_sim = add_enzyme_constraints(sim, ec_data)
# Out:
# Read LP format model from file /tmp/tmpxpcdyf40.lp
# Reading time = 0.01 seconds
# : 1135 rows, 2406 columns, 9502 nonzeros
# Converting to irreversible: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1203/1203 [00:06<00:00, 198.33it/s]
# Adding gene species: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 503/503 [00:02<00:00, 223.52it/s]
# Adding proteins usage to reactions:   0%|                                                                                                                                                                                                                                                                                                          | 0/2310 [00:00<?, ?it/s]/home/mmartins/anaconda3/envs/tmcom/lib/python3.9/site-packages/cobra/core/group.py:147: UserWarning: need to pass in a list
#   warn("need to pass in a list")
# Adding proteins usage to reactions: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2310/2310 [01:22<00:00, 27.98it/s]

# %% [markdown]
# ### Protein pool usage

# %%
res = ec_sim.simulate()
print(res)
# Out:
# objective: 60.78973722691819
# Status: OPTIMAL
# Method:SimulationMethod.FBA

# %%
res.find('pool')
# Out:
#                         Flux rate
# Reaction ID
# prot_pool_exchange  134016.314386

# %% [markdown]
# ### Save the model

# %%
write_sbml_model(ec_sim.model,f"../models/ec/ec_{model_id}.xml")

# %%
env = Environment.complete(ec_sim, max_uptake=1000.0, inplace=False)

env['prot_pool_exchange']=(0,0.8)

ec_sim.simulate(constraints=env)
# Out:
# objective: 0.001558568530208206
# Status: OPTIMAL
# Method:SimulationMethod.FBA
