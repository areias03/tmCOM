# %%
import pandas as pd
import numpy as np
from cobra.io import read_sbml_model
from tqdm.auto import tqdm

# %%
from os import listdir
from os.path import isfile, join

mypath = '../models/non-ec/'

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
print(onlyfiles)
# Out:
# ['Bacteroides_uniformis_ATCC_8492.xml', 'Coprococcus_comes_ATCC_27758.xml', 'Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586.xml', 'Streptococcus_salivarius_DSM_20560.xml', 'Streptococcus_parasanguinis_ATCC_15912.xml', 'Roseburia_intestinalis_L1_82.xml', 'Escherichia_coli_ED1a.xml', 'Bacteroides_thetaiotaomicron_VPI_5482.xml']

# %%
db_l = []

for file in tqdm(onlyfiles):
    file = mypath + file
    model = read_sbml_model(file)
    name = model.id
    name = str(name)
    name = name.strip('M_')
    id_n = name
    name = name.replace('_',' ')
    rxns = len(model.reactions)
    mets = len(model.metabolites)
    name_list = name.split(' ')
    genus = name_list[0]
    species = ' '.join(name_list[1::])
    for i in range(1,7):
        sam_n = i
        sample = f'sample_{sam_n}'
        abundace = np.random.randint(100,500)
        res = [id_n, genus, species, rxns, mets, file, sample, abundace]
        db_l.append(res)
    
db = pd.DataFrame(db_l, columns = ['id','genus','species','reactions','metabolites','file','sample_id','abundace'])
db
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#                                                    id          genus  \
# 0                     Bacteroides_uniformis_ATCC_8492    Bacteroides
# 1                     Bacteroides_uniformis_ATCC_8492    Bacteroides
# 2                     Bacteroides_uniformis_ATCC_8492    Bacteroides
# 3                     Bacteroides_uniformis_ATCC_8492    Bacteroides
# 4                     Bacteroides_uniformis_ATCC_8492    Bacteroides
# 5                     Bacteroides_uniformis_ATCC_8492    Bacteroides
# 6                        Coprococcus_comes_ATCC_27758    Coprococcus
# 7                        Coprococcus_comes_ATCC_27758    Coprococcus
# 8                        Coprococcus_comes_ATCC_27758    Coprococcus
# 9                        Coprococcus_comes_ATCC_27758    Coprococcus
# 10                       Coprococcus_comes_ATCC_27758    Coprococcus
# 11                       Coprococcus_comes_ATCC_27758    Coprococcus
# 12  Fusobacterium_nucleatum_subsp_nucleatum_ATCC_2...  Fusobacterium
# 13  Fusobacterium_nucleatum_subsp_nucleatum_ATCC_2...  Fusobacterium
# 14  Fusobacterium_nucleatum_subsp_nucleatum_ATCC_2...  Fusobacterium
# 15  Fusobacterium_nucleatum_subsp_nucleatum_ATCC_2...  Fusobacterium
# 16  Fusobacterium_nucleatum_subsp_nucleatum_ATCC_2...  Fusobacterium
# 17  Fusobacterium_nucleatum_subsp_nucleatum_ATCC_2...  Fusobacterium
# 18                 Streptococcus_salivarius_DSM_20560  Streptococcus
# 19                 Streptococcus_salivarius_DSM_20560  Streptococcus
# 20                 Streptococcus_salivarius_DSM_20560  Streptococcus
# 21                 Streptococcus_salivarius_DSM_20560  Streptococcus
# 22                 Streptococcus_salivarius_DSM_20560  Streptococcus
# 23                 Streptococcus_salivarius_DSM_20560  Streptococcus
# 24             Streptococcus_parasanguinis_ATCC_15912  Streptococcus
# 25             Streptococcus_parasanguinis_ATCC_15912  Streptococcus
# 26             Streptococcus_parasanguinis_ATCC_15912  Streptococcus
# 27             Streptococcus_parasanguinis_ATCC_15912  Streptococcus
# 28             Streptococcus_parasanguinis_ATCC_15912  Streptococcus
# 29             Streptococcus_parasanguinis_ATCC_15912  Streptococcus
# 30                       Roseburia_intestinalis_L1_82      Roseburia
# 31                       Roseburia_intestinalis_L1_82      Roseburia
# 32                       Roseburia_intestinalis_L1_82      Roseburia
# 33                       Roseburia_intestinalis_L1_82      Roseburia
# 34                       Roseburia_intestinalis_L1_82      Roseburia
# 35                       Roseburia_intestinalis_L1_82      Roseburia
# 36                              Escherichia_coli_ED1a    Escherichia
# 37                              Escherichia_coli_ED1a    Escherichia
# 38                              Escherichia_coli_ED1a    Escherichia
# 39                              Escherichia_coli_ED1a    Escherichia
# 40                              Escherichia_coli_ED1a    Escherichia
# 41                              Escherichia_coli_ED1a    Escherichia
# 42              Bacteroides_thetaiotaomicron_VPI_5482    Bacteroides
# 43              Bacteroides_thetaiotaomicron_VPI_5482    Bacteroides
# 44              Bacteroides_thetaiotaomicron_VPI_5482    Bacteroides
# 45              Bacteroides_thetaiotaomicron_VPI_5482    Bacteroides
# 46              Bacteroides_thetaiotaomicron_VPI_5482    Bacteroides
# 47              Bacteroides_thetaiotaomicron_VPI_5482    Bacteroides
#
#                                  species  reactions  metabolites  \
# 0                    uniformis ATCC 8492       2686         2204
# 1                    uniformis ATCC 8492       2686         2204
# 2                    uniformis ATCC 8492       2686         2204
# 3                    uniformis ATCC 8492       2686         2204
# 4                    uniformis ATCC 8492       2686         2204
# 5                    uniformis ATCC 8492       2686         2204
# 6                       comes ATCC 27758       1034          984
# 7                       comes ATCC 27758       1034          984
# 8                       comes ATCC 27758       1034          984
# 9                       comes ATCC 27758       1034          984
# 10                      comes ATCC 27758       1034          984
# 11                      comes ATCC 27758       1034          984
# 12  nucleatum subsp nucleatum ATCC 25586       1203         1135
# 13  nucleatum subsp nucleatum ATCC 25586       1203         1135
# 14  nucleatum subsp nucleatum ATCC 25586       1203         1135
# 15  nucleatum subsp nucleatum ATCC 25586       1203         1135
# 16  nucleatum subsp nucleatum ATCC 25586       1203         1135
# 17  nucleatum subsp nucleatum ATCC 25586       1203         1135
# 18                  salivarius DSM 20560        939          852
# 19                  salivarius DSM 20560        939          852
# 20                  salivarius DSM 20560        939          852
# 21                  salivarius DSM 20560        939          852
# 22                  salivarius DSM 20560        939          852
# 23                  salivarius DSM 20560        939          852
# 24              parasanguinis ATCC 15912       1258         1231
# 25              parasanguinis ATCC 15912       1258         1231
# 26              parasanguinis ATCC 15912       1258         1231
# 27              parasanguinis ATCC 15912       1258         1231
# 28              parasanguinis ATCC 15912       1258         1231
# 29              parasanguinis ATCC 15912       1258         1231
# 30                    intestinalis L1 82       1983         1691
# 31                    intestinalis L1 82       1983         1691
# 32                    intestinalis L1 82       1983         1691
# 33                    intestinalis L1 82       1983         1691
# 34                    intestinalis L1 82       1983         1691
# 35                    intestinalis L1 82       1983         1691
# 36                             coli ED1a       3586         3119
# 37                             coli ED1a       3586         3119
# 38                             coli ED1a       3586         3119
# 39                             coli ED1a       3586         3119
# 40                             coli ED1a       3586         3119
# 41                             coli ED1a       3586         3119
# 42             thetaiotaomicron VPI 5482       2438         2041
# 43             thetaiotaomicron VPI 5482       2438         2041
# 44             thetaiotaomicron VPI 5482       2438         2041
# 45             thetaiotaomicron VPI 5482       2438         2041
# 46             thetaiotaomicron VPI 5482       2438         2041
# 47             thetaiotaomicron VPI 5482       2438         2041
#
#                                                  file sample_id  abundace
# 0   ../models/non-ec/Bacteroides_uniformis_ATCC_84...  sample_1       386
# 1   ../models/non-ec/Bacteroides_uniformis_ATCC_84...  sample_2       239
# 2   ../models/non-ec/Bacteroides_uniformis_ATCC_84...  sample_3       193
# 3   ../models/non-ec/Bacteroides_uniformis_ATCC_84...  sample_4       155
# 4   ../models/non-ec/Bacteroides_uniformis_ATCC_84...  sample_5       246
# 5   ../models/non-ec/Bacteroides_uniformis_ATCC_84...  sample_6       212
# 6   ../models/non-ec/Coprococcus_comes_ATCC_27758.xml  sample_1       341
# 7   ../models/non-ec/Coprococcus_comes_ATCC_27758.xml  sample_2       479
# 8   ../models/non-ec/Coprococcus_comes_ATCC_27758.xml  sample_3       426
# 9   ../models/non-ec/Coprococcus_comes_ATCC_27758.xml  sample_4       315
# 10  ../models/non-ec/Coprococcus_comes_ATCC_27758.xml  sample_5       294
# 11  ../models/non-ec/Coprococcus_comes_ATCC_27758.xml  sample_6       214
# 12  ../models/non-ec/Fusobacterium_nucleatum_subsp...  sample_1       455
# 13  ../models/non-ec/Fusobacterium_nucleatum_subsp...  sample_2       448
# 14  ../models/non-ec/Fusobacterium_nucleatum_subsp...  sample_3       463
# 15  ../models/non-ec/Fusobacterium_nucleatum_subsp...  sample_4       379
# 16  ../models/non-ec/Fusobacterium_nucleatum_subsp...  sample_5       192
# 17  ../models/non-ec/Fusobacterium_nucleatum_subsp...  sample_6       248
# 18  ../models/non-ec/Streptococcus_salivarius_DSM_...  sample_1       125
# 19  ../models/non-ec/Streptococcus_salivarius_DSM_...  sample_2       264
# 20  ../models/non-ec/Streptococcus_salivarius_DSM_...  sample_3       281
# 21  ../models/non-ec/Streptococcus_salivarius_DSM_...  sample_4       193
# 22  ../models/non-ec/Streptococcus_salivarius_DSM_...  sample_5       465
# 23  ../models/non-ec/Streptococcus_salivarius_DSM_...  sample_6       239
# 24  ../models/non-ec/Streptococcus_parasanguinis_A...  sample_1       210
# 25  ../models/non-ec/Streptococcus_parasanguinis_A...  sample_2       496
# 26  ../models/non-ec/Streptococcus_parasanguinis_A...  sample_3       124
# 27  ../models/non-ec/Streptococcus_parasanguinis_A...  sample_4       147
# 28  ../models/non-ec/Streptococcus_parasanguinis_A...  sample_5       437
# 29  ../models/non-ec/Streptococcus_parasanguinis_A...  sample_6       190
# 30  ../models/non-ec/Roseburia_intestinalis_L1_82.xml  sample_1       262
# 31  ../models/non-ec/Roseburia_intestinalis_L1_82.xml  sample_2       286
# 32  ../models/non-ec/Roseburia_intestinalis_L1_82.xml  sample_3       443
# 33  ../models/non-ec/Roseburia_intestinalis_L1_82.xml  sample_4       236
# 34  ../models/non-ec/Roseburia_intestinalis_L1_82.xml  sample_5       204
# 35  ../models/non-ec/Roseburia_intestinalis_L1_82.xml  sample_6       342
# 36         ../models/non-ec/Escherichia_coli_ED1a.xml  sample_1       205
# 37         ../models/non-ec/Escherichia_coli_ED1a.xml  sample_2       195
# 38         ../models/non-ec/Escherichia_coli_ED1a.xml  sample_3       132
# 39         ../models/non-ec/Escherichia_coli_ED1a.xml  sample_4       186
# 40         ../models/non-ec/Escherichia_coli_ED1a.xml  sample_5       314
# 41         ../models/non-ec/Escherichia_coli_ED1a.xml  sample_6       353
# 42  ../models/non-ec/Bacteroides_thetaiotaomicron_...  sample_1       493
# 43  ../models/non-ec/Bacteroides_thetaiotaomicron_...  sample_2       437
# 44  ../models/non-ec/Bacteroides_thetaiotaomicron_...  sample_3       333
# 45  ../models/non-ec/Bacteroides_thetaiotaomicron_...  sample_4       488
# 46  ../models/non-ec/Bacteroides_thetaiotaomicron_...  sample_5       464
# 47  ../models/non-ec/Bacteroides_thetaiotaomicron_...  sample_6       229

# %%
from micom.workflows import build

manifest = build(db, out_folder="micom", model_db=None, cutoff=0.0001, threads=2)
# Out:
# Output()
# Set parameter Username
# Set parameter Username
# Set parameter Username
# Set parameter Username
# Set parameter Username
# Set parameter Username

# %%
manifest
# Out:
#   sample_id             file
# 0  sample_1  sample_1.pickle
# 1  sample_2  sample_2.pickle
# 2  sample_3  sample_3.pickle
# 3  sample_4  sample_4.pickle
# 4  sample_5  sample_5.pickle
# 5  sample_6  sample_6.pickle

# %%
from micom import load_pickle

com1 = load_pickle("models/sample_1.pickle")
print(len(com1.reactions))
# Out:
# 305

# %%
from micom.media import minimal_medium

med = minimal_medium(com1, 0.8)
res_m = []

for k in med.keys():
    print(f'Reaction: {k}, Flux: {med[k]}')
    rx = k
    flux = med[k]
    met = k.strip('EX_')
    res = [k,k,flux,met]
    res_m.append(res)
    
min_med = pd.DataFrame(res_m, columns = ['reaction','reaction','flux','metabolite'])
min_med
# Out:
# Reaction: EX_glc__D_m, Flux: 10.0
# Reaction: EX_nh4_m, Flux: 4.362240000000001
# Reaction: EX_o2_m, Flux: 18.579253333333554
# Reaction: EX_pi_m, Flux: 2.942960000000048
#       reaction     reaction       flux metabolite
# 0  EX_glc__D_m  EX_glc__D_m  10.000000   glc__D_m
# 1     EX_nh4_m     EX_nh4_m   4.362240      nh4_m
# 2      EX_o2_m      EX_o2_m  18.579253       o2_m
# 3      EX_pi_m      EX_pi_m   2.942960       pi_m

# %%
from micom.data import test_medium
from micom.qiime_formats import load_qiime_medium

test_med = load_qiime_medium(test_medium)
test_med
# Out:
#                 reaction       flux metabolite
# reaction
# EX_glc__D_m  EX_glc__D_m  10.000000   glc__D_m
# EX_nh4_m        EX_nh4_m   4.362240      nh4_m
# EX_o2_m          EX_o2_m  18.579253       o2_m
# EX_pi_m          EX_pi_m   2.942960       pi_m

# %%
from micom.workflows import grow

res = grow(manifest, model_folder="micom", medium=test_med, tradeoff=1.0, threads=2)
# Out:
# Output()
# Set parameter Username
# Set parameter Username
# [01:26:58] WARNING  There does not seem to be any carbon source ]8;id=23361;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py\community.py]8;;\:]8;id=546398;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py#678\678]8;;\
#                     in your medium. Please double-check your
#                     medium IDs.
# [01:26:58] WARNING  There does not seem to be any carbon source ]8;id=389982;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py\community.py]8;;\:]8;id=106684;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py#678\678]8;;\
#                     in your medium. Please double-check your
#                     medium IDs.
# Set parameter Username
# Set parameter Username
# [01:27:04] WARNING  There does not seem to be any carbon source ]8;id=938952;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py\community.py]8;;\:]8;id=786285;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py#678\678]8;;\
#                     in your medium. Please double-check your
#                     medium IDs.
# [01:27:05] WARNING  There does not seem to be any carbon source ]8;id=721301;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py\community.py]8;;\:]8;id=314153;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py#678\678]8;;\
#                     in your medium. Please double-check your
#                     medium IDs.
# Set parameter Username
# Set parameter Username
# [01:27:11] WARNING  There does not seem to be any carbon source ]8;id=471443;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py\community.py]8;;\:]8;id=317706;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py#678\678]8;;\
#                     in your medium. Please double-check your
#                     medium IDs.
# [01:27:11] WARNING  There does not seem to be any carbon source ]8;id=451771;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py\community.py]8;;\:]8;id=846122;file:///usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/micom/community.py#678\678]8;;\
#                     in your medium. Please double-check your
#                     medium IDs.

# %%
from micom.workflows import tradeoff

tradeoff_rates = tradeoff(manifest, model_folder="micom", medium=medium, threads=2)
tradeoff_rates.groupby("tradeoff").apply(
    lambda df: (df.growth_rate > 1e-6).sum()).reset_index()

# %%
from micom.viz import plot_tradeoff

pl = plot_tradeoff(tradeoff_rates, filename="tradeoff.html")
pl.view()

# %%
from micom.viz import plot_growth

pl = plot_growth(res, filename="growth_rates.html")

# %%
pl.view()
