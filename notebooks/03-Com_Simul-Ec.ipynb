# %%
from cobra.io import read_sbml_model
from reframed.io.sbml import load_cbmodel
from mewpy import get_simulator
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from tmcom.com import CommunityModel

# %%
bt = read_sbml_model('../models/ec/ec_Bacteroides_thetaiotaomicron_VPI_5482.xml')

bu = read_sbml_model('../models/ec/ec_Bacteroides_uniformis_ATCC_8492.xml')

ec = read_sbml_model('../models/ec/ec_Escherichia_coli_ED1a.xml')

fn = read_sbml_model('../models/ec/ec_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586.xml')

ri = read_sbml_model('../models/ec/ec_Roseburia_intestinalis_L1_82.xml')

sp = read_sbml_model('../models/ec/ec_Streptococcus_parasanguinis_ATCC_15912.xml')

ss = read_sbml_model('../models/ec/ec_Streptococcus_salivarius_DSM_20560.xml')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-01

# %%
model_list = [bt,bu,ec,fn,ri,sp,ss]
for m in model_list:
    print(f'{m.id}: {len(m.reactions)}')
# Out:
# M_Bacteroides_thetaiotaomicron_VPI_5482: 4740
# M_Bacteroides_uniformis_ATCC_8492: 5523
# M_Escherichia_coli_ED1a: 6916
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586: 2310
# M_Roseburia_intestinalis_L1_82: 4974
# M_Streptococcus_parasanguinis_ATCC_15912: 2764
# M_Streptococcus_salivarius_DSM_20560: 1842

# %%
for m in model_list:
    print(f'{m.id}: {len(m.genes)}')
# Out:
# M_Bacteroides_thetaiotaomicron_VPI_5482: 823
# M_Bacteroides_uniformis_ATCC_8492: 821
# M_Escherichia_coli_ED1a: 1427
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586: 503
# M_Roseburia_intestinalis_L1_82: 853
# M_Streptococcus_parasanguinis_ATCC_15912: 899
# M_Streptococcus_salivarius_DSM_20560: 525

# %%
for m in model_list:
    print(f'{m.id}: {len(m.metabolites)}')
# Out:
# M_Bacteroides_thetaiotaomicron_VPI_5482: 2865
# M_Bacteroides_uniformis_ATCC_8492: 3026
# M_Escherichia_coli_ED1a: 4547
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586: 1639
# M_Roseburia_intestinalis_L1_82: 2545
# M_Streptococcus_parasanguinis_ATCC_15912: 2131
# M_Streptococcus_salivarius_DSM_20560: 1378

# %%
for m in model_list:
    print(f'{m.id}: {len(m.demands)}')
# Out:
# M_Bacteroides_thetaiotaomicron_VPI_5482: 424
# M_Bacteroides_uniformis_ATCC_8492: 423
# M_Escherichia_coli_ED1a: 1031
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586: 383
# M_Roseburia_intestinalis_L1_82: 594
# M_Streptococcus_parasanguinis_ATCC_15912: 598
# M_Streptococcus_salivarius_DSM_20560: 400

# %%
for m in model_list:
    print(f'{m.id}: {len(m.exchanges)}')
# Out:
# M_Bacteroides_thetaiotaomicron_VPI_5482: 1072
# M_Bacteroides_uniformis_ATCC_8492: 918
# M_Escherichia_coli_ED1a: 1112
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586: 266
# M_Roseburia_intestinalis_L1_82: 930
# M_Streptococcus_parasanguinis_ATCC_15912: 250
# M_Streptococcus_salivarius_DSM_20560: 206

# %%
from mewpy.cobra.com import *
#import seaborn as sns
#import matplotlib.pyplot as plt

mets, rxns, over = jaccard_similarity_matrices([bt,bu,ec,fn,ri,sp,ss])

# %%
mets
# Out:
#                                                     M_Bacteroides_thetaiotaomicron_VPI_5482  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                            1.000000
# M_Bacteroides_uniformis_ATCC_8492                                                  0.439287
# M_Escherichia_coli_ED1a                                                            0.313020
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                 0.242140
# M_Roseburia_intestinalis_L1_82                                                     0.276244
# M_Streptococcus_parasanguinis_ATCC_15912                                           0.183886
# M_Streptococcus_salivarius_DSM_20560                                               0.206426
#
#                                                     M_Bacteroides_uniformis_ATCC_8492  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                      0.439287
# M_Bacteroides_uniformis_ATCC_8492                                            1.000000
# M_Escherichia_coli_ED1a                                                      0.372418
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                           0.227632
# M_Roseburia_intestinalis_L1_82                                               0.371830
# M_Streptococcus_parasanguinis_ATCC_15912                                     0.176860
# M_Streptococcus_salivarius_DSM_20560                                         0.191558
#
#                                                     M_Escherichia_coli_ED1a  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                            0.313020
# M_Bacteroides_uniformis_ATCC_8492                                  0.372418
# M_Escherichia_coli_ED1a                                            1.000000
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                 0.207731
# M_Roseburia_intestinalis_L1_82                                     0.289220
# M_Streptococcus_parasanguinis_ATCC_15912                           0.205633
# M_Streptococcus_salivarius_DSM_20560                               0.159945
#
#                                                     M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                                      0.242140
# M_Bacteroides_uniformis_ATCC_8492                                                            0.227632
# M_Escherichia_coli_ED1a                                                                      0.207731
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                           1.000000
# M_Roseburia_intestinalis_L1_82                                                               0.228060
# M_Streptococcus_parasanguinis_ATCC_15912                                                     0.247931
# M_Streptococcus_salivarius_DSM_20560                                                         0.282738
#
#                                                     M_Roseburia_intestinalis_L1_82  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                   0.276244
# M_Bacteroides_uniformis_ATCC_8492                                         0.371830
# M_Escherichia_coli_ED1a                                                   0.289220
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                        0.228060
# M_Roseburia_intestinalis_L1_82                                            1.000000
# M_Streptococcus_parasanguinis_ATCC_15912                                  0.198053
# M_Streptococcus_salivarius_DSM_20560                                      0.222118
#
#                                                     M_Streptococcus_parasanguinis_ATCC_15912  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                             0.183886
# M_Bacteroides_uniformis_ATCC_8492                                                   0.176860
# M_Escherichia_coli_ED1a                                                             0.205633
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                  0.247931
# M_Roseburia_intestinalis_L1_82                                                      0.198053
# M_Streptococcus_parasanguinis_ATCC_15912                                            1.000000
# M_Streptococcus_salivarius_DSM_20560                                                0.289599
#
#                                                     M_Streptococcus_salivarius_DSM_20560
# M_Bacteroides_thetaiotaomicron_VPI_5482                                         0.206426
# M_Bacteroides_uniformis_ATCC_8492                                               0.191558
# M_Escherichia_coli_ED1a                                                         0.159945
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                              0.282738
# M_Roseburia_intestinalis_L1_82                                                  0.222118
# M_Streptococcus_parasanguinis_ATCC_15912                                        0.289599
# M_Streptococcus_salivarius_DSM_20560                                            1.000000

# %% [raw]
# labels = ['Bt','Bu','Ec','Fn','Ri','Sp','Ss']
# g = sns.heatmap(mets, cmap = 'vlag',annot=True,xticklabels=labels,yticklabels=labels)
# g.tick_params(axis='both', which='both', length=0)
# g.set_ylabel('')
# plt.savefig('../data/images/ec_metsover.png', bbox_inches='tight')

# %%
rxns
# Out:
#                                                     M_Bacteroides_thetaiotaomicron_VPI_5482  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                            1.000000
# M_Bacteroides_uniformis_ATCC_8492                                                  0.276175
# M_Escherichia_coli_ED1a                                                            0.344871
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                 0.200409
# M_Roseburia_intestinalis_L1_82                                                     0.099989
# M_Streptococcus_parasanguinis_ATCC_15912                                           0.140946
# M_Streptococcus_salivarius_DSM_20560                                               0.152311
#
#                                                     M_Bacteroides_uniformis_ATCC_8492  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                      0.276175
# M_Bacteroides_uniformis_ATCC_8492                                            1.000000
# M_Escherichia_coli_ED1a                                                      0.214390
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                           0.054240
# M_Roseburia_intestinalis_L1_82                                               0.259388
# M_Streptococcus_parasanguinis_ATCC_15912                                     0.019562
# M_Streptococcus_salivarius_DSM_20560                                         0.016423
#
#                                                     M_Escherichia_coli_ED1a  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                            0.344871
# M_Bacteroides_uniformis_ATCC_8492                                  0.214390
# M_Escherichia_coli_ED1a                                            1.000000
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                 0.201928
# M_Roseburia_intestinalis_L1_82                                     0.084260
# M_Streptococcus_parasanguinis_ATCC_15912                           0.180776
# M_Streptococcus_salivarius_DSM_20560                               0.138290
#
#                                                     M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                                      0.200409
# M_Bacteroides_uniformis_ATCC_8492                                                            0.054240
# M_Escherichia_coli_ED1a                                                                      0.201928
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                           1.000000
# M_Roseburia_intestinalis_L1_82                                                               0.030414
# M_Streptococcus_parasanguinis_ATCC_15912                                                     0.207520
# M_Streptococcus_salivarius_DSM_20560                                                         0.221536
#
#                                                     M_Roseburia_intestinalis_L1_82  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                   0.099989
# M_Bacteroides_uniformis_ATCC_8492                                         0.259388
# M_Escherichia_coli_ED1a                                                   0.084260
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                        0.030414
# M_Roseburia_intestinalis_L1_82                                            1.000000
# M_Streptococcus_parasanguinis_ATCC_15912                                  0.037126
# M_Streptococcus_salivarius_DSM_20560                                      0.034765
#
#                                                     M_Streptococcus_parasanguinis_ATCC_15912  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                             0.140946
# M_Bacteroides_uniformis_ATCC_8492                                                   0.019562
# M_Escherichia_coli_ED1a                                                             0.180776
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                  0.207520
# M_Roseburia_intestinalis_L1_82                                                      0.037126
# M_Streptococcus_parasanguinis_ATCC_15912                                            1.000000
# M_Streptococcus_salivarius_DSM_20560                                                0.322044
#
#                                                     M_Streptococcus_salivarius_DSM_20560
# M_Bacteroides_thetaiotaomicron_VPI_5482                                         0.152311
# M_Bacteroides_uniformis_ATCC_8492                                               0.016423
# M_Escherichia_coli_ED1a                                                         0.138290
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                              0.221536
# M_Roseburia_intestinalis_L1_82                                                  0.034765
# M_Streptococcus_parasanguinis_ATCC_15912                                        0.322044
# M_Streptococcus_salivarius_DSM_20560                                            1.000000

# %% [raw]
# g = sns.heatmap(rxns, cmap = 'vlag',annot=True,xticklabels=labels,yticklabels=labels)
# g.tick_params(axis='both', which='both', length=0)
# g.set_ylabel('')
# plt.savefig('../data/images/ec_rxnsover.png', bbox_inches='tight')

# %%
over
# Out:
#                                                     M_Bacteroides_thetaiotaomicron_VPI_5482  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                            1.000000
# M_Bacteroides_uniformis_ATCC_8492                                                  0.802536
# M_Escherichia_coli_ED1a                                                            0.644578
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                 0.122483
# M_Roseburia_intestinalis_L1_82                                                     0.708191
# M_Streptococcus_parasanguinis_ATCC_15912                                           0.110924
# M_Streptococcus_salivarius_DSM_20560                                               0.097938
#
#                                                     M_Bacteroides_uniformis_ATCC_8492  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                      0.802536
# M_Bacteroides_uniformis_ATCC_8492                                            1.000000
# M_Escherichia_coli_ED1a                                                      0.703020
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                           0.123340
# M_Roseburia_intestinalis_L1_82                                               0.815324
# M_Streptococcus_parasanguinis_ATCC_15912                                     0.123077
# M_Streptococcus_salivarius_DSM_20560                                         0.091262
#
#                                                     M_Escherichia_coli_ED1a  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                            0.644578
# M_Bacteroides_uniformis_ATCC_8492                                  0.703020
# M_Escherichia_coli_ED1a                                            1.000000
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                 0.200348
# M_Roseburia_intestinalis_L1_82                                     0.739353
# M_Streptococcus_parasanguinis_ATCC_15912                           0.198944
# M_Streptococcus_salivarius_DSM_20560                               0.166372
#
#                                                     M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_25586  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                                      0.122483
# M_Bacteroides_uniformis_ATCC_8492                                                            0.123340
# M_Escherichia_coli_ED1a                                                                      0.200348
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                           1.000000
# M_Roseburia_intestinalis_L1_82                                                               0.174853
# M_Streptococcus_parasanguinis_ATCC_15912                                                     0.535714
# M_Streptococcus_salivarius_DSM_20560                                                         0.503185
#
#                                                     M_Roseburia_intestinalis_L1_82  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                   0.708191
# M_Bacteroides_uniformis_ATCC_8492                                         0.815324
# M_Escherichia_coli_ED1a                                                   0.739353
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                        0.174853
# M_Roseburia_intestinalis_L1_82                                            1.000000
# M_Streptococcus_parasanguinis_ATCC_15912                                  0.194332
# M_Streptococcus_salivarius_DSM_20560                                      0.168724
#
#                                                     M_Streptococcus_parasanguinis_ATCC_15912  \
# M_Bacteroides_thetaiotaomicron_VPI_5482                                             0.110924
# M_Bacteroides_uniformis_ATCC_8492                                                   0.123077
# M_Escherichia_coli_ED1a                                                             0.198944
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                                  0.535714
# M_Roseburia_intestinalis_L1_82                                                      0.194332
# M_Streptococcus_parasanguinis_ATCC_15912                                            1.000000
# M_Streptococcus_salivarius_DSM_20560                                                0.652174
#
#                                                     M_Streptococcus_salivarius_DSM_20560
# M_Bacteroides_thetaiotaomicron_VPI_5482                                         0.097938
# M_Bacteroides_uniformis_ATCC_8492                                               0.091262
# M_Escherichia_coli_ED1a                                                         0.166372
# M_Fusobacterium_nucleatum_subsp_nucleatum_ATCC_...                              0.503185
# M_Roseburia_intestinalis_L1_82                                                  0.168724
# M_Streptococcus_parasanguinis_ATCC_15912                                        0.652174
# M_Streptococcus_salivarius_DSM_20560                                            1.000000

# %% [raw]
# g = sns.heatmap(over, cmap = 'vlag',annot=True,xticklabels=labels,yticklabels=labels)
# g.tick_params(axis='both', which='both', length=0)
# g.set_ylabel('')
# plt.savefig('../data/images/ec_uptakeover.png', bbox_inches='tight')

# %%
sample1 = CommunityModel([bt,ec],flavor='reframed', abundances = [1,0.5])
sample2 = CommunityModel([bt,bu,fn],flavor='reframed', add_compartments=True, merge_biomasses=True)
sample3 = CommunityModel([bt,bu,ri],flavor='reframed', add_compartments=True, merge_biomasses=True)
sample4 = CommunityModel([bt,bu,sp],flavor='reframed', add_compartments=True, merge_biomasses=True)
sample5 = CommunityModel([bt,bu,ss],flavor='reframed', add_compartments=True, merge_biomasses=True)

# %%
sim1 = sample1.get_community_model()
# Out:
# Adding M_Bacteroides_thetaiotaomicron_VPI_5482
# Adding internal compartments: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 95.38it/s]
# Adding metabolites: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2865/2865 [00:00<00:00, 52140.80it/s]
# Adding genes: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 823/823 [00:00<00:00, 61810.16it/s]
# Adding reactions: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4740/4740 [06:27<00:00, 12.25it/s]
# Adding M_Escherichia_coli_ED1a
# Adding internal compartments: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 56.13it/s]
# Adding metabolites: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4547/4547 [00:00<00:00, 26809.84it/s]
# Adding genes: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1427/1427 [00:00<00:00, 60827.79it/s]
# Adding reactions: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6916/6916 [14:46<00:00,  7.80it/s]
# Adding exchange reactions: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 664/664 [00:00<00:00, 104323.41it/s]

# %%
sim1.metabolites
# Out:
# ['M_10fthf5glu[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10fthf[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10m3hddcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10m3hundecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10m3oddcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10m3oundecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10mddcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10mtddec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10mtundec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_10mundecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_11m3hddcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_11m3oddcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_11mddcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_11mtddec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12m3hmyrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12m3htridecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12m3omyrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12m3otridecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12mmyrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12mtmrs2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12mtridecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12mttritec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12ppd_S[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12ppd_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_12ppd_S[e]',
#  'M_12ppd_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_13dpg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_13m3hmyrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_13m3omyrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_13mmyrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_13mtmrs2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14m3hpalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14m3hpentdecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14m3opalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14m3opentdecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14mpalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14mpentdecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14mtpalm2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_14mtpentdec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_15m3hpalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_15m3opalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_15mpalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_15mtpalm2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1aihpdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1aipdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1ddecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hdec9eg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hibup_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hibup_S[e]',
#  'M_1hibup_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hibupglu_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hibupglu_S[e]',
#  'M_1hibupglu_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hmdgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1hmdgluc[e]',
#  'M_1hmdgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1ihdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1ihpdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1ipdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1itdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1odec11eg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1odecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1ohmdz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1ohmdz[e]',
#  'M_1ohmdz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1p3h5c[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1pyr5c[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1tdec7eg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_1tdecg3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23camp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23ccmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23cgmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23cump[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23dhdp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23dhmb[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_23dhmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_25aics[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_25dhpp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_25drapp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_26dap_LL[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_26dap_M[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ahbut[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ahhmd[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ahhmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ameph[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2aobut[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2c25dho[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2c4mthzep[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2cpr5p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2dda7p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ddg6p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ddglcn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2dhp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2dmmq8[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2dmmql8[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2dr1p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2dr5p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2h3oppan[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvacid[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvacid[e]',
#  'M_2hatvacid[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvacidgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvacidgluc[e]',
#  'M_2hatvacidgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvlac[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvlac[e]',
#  'M_2hatvlac[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvlacgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hatvlacgluc[e]',
#  'M_2hatvlacgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hibup_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hibup_S[e]',
#  'M_2hibup_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hibupglu_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2hibupglu_S[e]',
#  'M_2hibupglu_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ins[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ippm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2mahmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2mbcoa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2mbutACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2me4p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2mecdp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2mmal[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2mpropACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2obut[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_cbz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_cbz[e]',
#  'M_2oh_cbz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_cbz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_cbz_glc[e]',
#  'M_2oh_cbz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_mtz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_mtz[e]',
#  'M_2oh_mtz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_mtz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2oh_mtz_glc[e]',
#  'M_2oh_mtz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ombz[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2omfuc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2omfuc[e]',
#  'M_2omfuc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2ommb[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2omxyl[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2omxyl[e]',
#  'M_2omxyl[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2p4c2me[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2pg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2pglyc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2s5epchc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_2shchc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_33hmeoxobut[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_34hpp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_36dahx[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3a2opp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3amp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3c2hmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3c3hmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3c4mop[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3cmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ddlhept[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ddlhept[e]',
#  'M_3ddlhept[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3dhq[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3dhsk[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3gmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3h3mop[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3haACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hddecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hdecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hgACPm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hhexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hibup_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hibup_S[e]',
#  'M_3hibup_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hibupglu_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hibupglu_S[e]',
#  'M_3hibupglu_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hmrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hoctACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hoctaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hpACPm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3hpalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ig3p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3mbutACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3meacmp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3meacmp[e]',
#  'M_3meacmp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3mob[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3mop[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oddecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3odecACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ogACPm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_cbz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_cbz[e]',
#  'M_3oh_cbz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_cbz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_cbz_glc[e]',
#  'M_3oh_cbz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_dlor[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_dlor[e]',
#  'M_3oh_dlor[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_dlor_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_dlor_glc[e]',
#  'M_3oh_dlor_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mdea[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mdea[e]',
#  'M_3oh_mdea[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mdea_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mdea_glc[e]',
#  'M_3oh_mdea_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mxn[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mxn[e]',
#  'M_3oh_mxn[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mxn_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3oh_mxn_glc[e]',
#  'M_3oh_mxn_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ohexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3omrsACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ooctACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ooctdACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3opACPm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3opalmACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3padsel[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3pg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3php[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3psme[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_3ump[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4abut[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4abut[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4abut[e]',
#  'M_4abut[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4abz[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4adcho[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4ahmmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4ampm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4c2me[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4dh_tpno[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4dh_tpno[e]',
#  'M_4dh_tpno[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4dh_tpno_1glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4dh_tpno_1glc[e]',
#  'M_4dh_tpno_1glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4gubut[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4gudbd[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4h2oglt[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hba[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hmdgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hmdgluc[e]',
#  'M_4hmdgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hphac[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hpro_LT[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hthdp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4hthr[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4izp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4m3hhexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4m3hpentACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4m3ohexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4m3opentACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4mhexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4mop[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4mpentACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4mpetz[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4mthex2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4mtpent2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_dcf[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_dcf[e]',
#  'M_4oh_dcf[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_dcf_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_dcf_glc[e]',
#  'M_4oh_dcf_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_kp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_kp[e]',
#  'M_4oh_kp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_kp_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_kp_glc[e]',
#  'M_4oh_kp_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_levole[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_levole[e]',
#  'M_4oh_levole[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_levole_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_levole_glc[e]',
#  'M_4oh_levole_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_meth[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_meth[e]',
#  'M_4oh_meth[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_meth_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_meth_glc[e]',
#  'M_4oh_meth_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_propl[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_propl[e]',
#  'M_4oh_propl[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_propl_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_propl_glc[e]',
#  'M_4oh_propl_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_trz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_trz[e]',
#  'M_4oh_trz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_trz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_trz_glc[e]',
#  'M_4oh_trz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_vcz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_vcz[e]',
#  'M_4oh_vcz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_vcz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4oh_vcz_glc[e]',
#  'M_4oh_vcz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4ohmdz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4ohmdz[e]',
#  'M_4ohmdz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4pasp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4per[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4ppan[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4ppcys[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_4r5au[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5aizc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5aop[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5aprbu[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5apru[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5forthf[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5fthf[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5m3hhexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5m3ohexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5mhexACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5mta[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5mthex2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5mthf[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5mtr[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5odhf2a[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5oh_sulfp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5oh_sulfp[e]',
#  'M_5oh_sulfp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5oh_sulfp_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5oh_sulfp_glc[e]',
#  'M_5oh_sulfp_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5ohfvs[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5ohfvs[e]',
#  'M_5ohfvs[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5ohfvsglu[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5ohfvsglu[e]',
#  'M_5ohfvsglu[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5prdmbz[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_5thf[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6bhglz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6bhglz[e]',
#  'M_6bhglz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6bhglzglc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6bhglzglc[e]',
#  'M_6bhglzglc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6hmhpt[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6hmhptpp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6m3hheptACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6m3hocACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6m3oheptACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6m3oocACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6mheptACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6mocACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6mthept2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6mtoct2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6ohfvs[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6ohfvs[e]',
#  'M_6ohfvs[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6ohfvsglu[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6ohfvsglu[e]',
#  'M_6ohfvsglu[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6pgc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_6pgl[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7a_czp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7a_czp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7a_czp[e]',
#  'M_7a_czp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7bhglz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7bhglz[e]',
#  'M_7bhglz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7bhglzglc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7bhglzglc[e]',
#  'M_7bhglzglc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7dhcdchol[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7dhcdchol[e]',
#  'M_7dhcdchol[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7m3hocACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7m3oocACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7mocACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7mtoct2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7ocholate[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7ocholate[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7ocholate[e]',
#  'M_7ocholate[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7oh_efv[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7oh_efv[e]',
#  'M_7oh_efv[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7oh_efv_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_7oh_efv_glc[e]',
#  'M_7oh_efv_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_814dioh_efv[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_814dioh_efv[e]',
#  'M_814dioh_efv[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_814dioh_efv_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_814dioh_efv_glc[e]',
#  'M_814dioh_efv_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8aonn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8m3hdcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8m3hnonACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8m3odcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8m3ononACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8mdcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8mnonACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8mtdec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8mtnon2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8oh_efv[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8oh_efv[e]',
#  'M_8oh_efv[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8oh_efv_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_8oh_efv_glc[e]',
#  'M_8oh_efv_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_9m3hdcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_9m3odcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_9mdcaACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_9mtdec2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_C02528[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_C02528[e]',
#  'M_C02528[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_CE5656[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_HC01104[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_HC01434[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_HC01651[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_HC01652[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_HC01710[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Largn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_N1aspmd[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_N_oh_phtn[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_N_oh_phtn[e]',
#  'M_N_oh_phtn[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_N_oh_phtn_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_N_oh_phtn_glc[e]',
#  'M_N_oh_phtn_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Naccitr_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_PGP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_PGPm1[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_6oh_warf[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_6oh_warf[e]',
#  'M_R_6oh_warf[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_6oh_warf_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_6oh_warf_glc[e]',
#  'M_R_6oh_warf_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_7oh_warf[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_7oh_warf[e]',
#  'M_R_7oh_warf[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_7oh_warf_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_7oh_warf_glc[e]',
#  'M_R_7oh_warf_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_8oh_warf[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_8oh_warf[e]',
#  'M_R_8oh_warf[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_8oh_warf_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_R_8oh_warf_glc[e]',
#  'M_R_8oh_warf_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_4oh_warf[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_4oh_warf[e]',
#  'M_S_4oh_warf[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_4oh_warf_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_4oh_warf_glc[e]',
#  'M_S_4oh_warf_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_6oh_warf[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_6oh_warf[e]',
#  'M_S_6oh_warf[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_6oh_warf_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_S_6oh_warf_glc[e]',
#  'M_S_6oh_warf_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Ser_Thr[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Ser_Thr[e]',
#  'M_Ser_Thr[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_T_antigen[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_T_antigen[e]',
#  'M_T_antigen[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Tn_antigen[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Tn_antigen[e]',
#  'M_Tn_antigen[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Tyr_ggn[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_Tyr_ggn[e]',
#  'M_Tyr_ggn[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aacoa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aact[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac[e]',
#  'M_ac[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac_amn_b_gly[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac_amn_b_gly[e]',
#  'M_ac_amn_b_gly[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac_amn_b_gly_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ac_amn_b_gly_glc[e]',
#  'M_ac_amn_b_gly_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acac[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acald[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acbdma14gapuc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_accoa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acerA[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acerA[e]',
#  'M_acerA[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acg5p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acg5sa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgal6p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgal[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgal[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgal[e]',
#  'M_acgal[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgalglcur[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgalglcur[e]',
#  'M_acgalglcur[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgalidour2s[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgalidour2s[e]',
#  'M_acgalidour2s[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgalidour[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgalidour[e]',
#  'M_acgalidour[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgam1p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgam6p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgam[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acgam[e]',
#  'M_acgam[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acglu[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_achms[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmalt[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmana[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmp[e]',
#  'M_acmp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmp_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmp_glc[e]',
#  'M_acmp_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmpglu[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acmpglu[e]',
#  'M_acmpglu[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acnam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acnam[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acnam[e]',
#  'M_acnam[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acon_C[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acorn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acryl[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_acser[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_actACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_actn_R[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_actp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ad[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adcobdam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ade[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adhlam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adn[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adn[e]',
#  'M_adn[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adocbi[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adocbip[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adocbl[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adocbl[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adocbl[e]',
#  'M_adocbl[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adphep_DD[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adphep_LD[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_adsel[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_agdpcbi[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_agm[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ahcys[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ahdt[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ai15tca1[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ai15tcaacgam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ai17tca1[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ai17tcaacgam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aicar[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aihpdcoa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aipdcoa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_air[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_akg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ala_B[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ala_D[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ala_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alaala[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alaasp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alac_S[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alagln[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alaglu[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alagly[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alahis[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alaleu[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alathr[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpro[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_4oh[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_4oh[e]',
#  'M_alpz_4oh[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_4oh_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_4oh_glc[e]',
#  'M_alpz_4oh_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_aoh[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_aoh[e]',
#  'M_alpz_aoh[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_aoh_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_alpz_aoh_glc[e]',
#  'M_alpz_aoh_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_altrn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am14[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am14[e]',
#  'M_am14[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am14_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am14_glc[e]',
#  'M_am14_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am1ccs[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am1ccs[e]',
#  'M_am1ccs[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am1cglc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am1cglc[e]',
#  'M_am1cglc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am5[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am5[e]',
#  'M_am5[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am5_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am5_glc[e]',
#  'M_am5_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am6[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am6[e]',
#  'M_am6[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am6_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_am6_glc[e]',
#  'M_am6_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amet[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ametam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio[e]',
#  'M_amio[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio_c[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio_c[e]',
#  'M_amio_c[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio_c_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio_c_glc[e]',
#  'M_amio_c_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amio_glc[e]',
#  'M_amio_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amn_b_gly[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amn_b_gly[e]',
#  'M_amn_b_gly[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amn_b_gly_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amn_b_gly_glc[e]',
#  'M_amn_b_gly_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amntd_m6[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amntd_m6[e]',
#  'M_amntd_m6[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amntd_m6_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amntd_m6_glc[e]',
#  'M_amntd_m6_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amob[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amopbut_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amylopect900[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amylopect900[e]',
#  'M_amylopect900[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amylose300[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_amylose300[e]',
#  'M_amylose300[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_anth[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_anzp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_anzp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_anzp[e]',
#  'M_anzp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_apio_D[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_apio_D[e]',
#  'M_apio_D[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_apoACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_apoC_Lys_btn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aps[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ara5p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arab_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arab_L[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arab_L[e]',
#  'M_arab_L[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabinan101[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabinan101[e]',
#  'M_arabinan101[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabinogal[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabinogal[e]',
#  'M_arabinogal[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabinoxyl[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabinoxyl[e]',
#  'M_arabinoxyl[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabttr[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arabttr[e]',
#  'M_arabttr[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arg_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_argsuc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arsenb[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arsenb[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_arsenb[e]',
#  'M_arsenb[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_asn_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_asp_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_aspsa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvacid[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvacid[e]',
#  'M_atvacid[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvacylgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvacylgluc[e]',
#  'M_atvacylgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvethgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvethgluc[e]',
#  'M_atvethgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvlac[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvlac[e]',
#  'M_atvlac[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvlacgluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_atvlacgluc[e]',
#  'M_atvlacgluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bhpm[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bhpm[e]',
#  'M_bhpm[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bhpm_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bhpm_glc[e]',
#  'M_bhpm_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_355[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_355[e]',
#  'M_bilr_355[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M10[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M10[e]',
#  'M_bilr_M10[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M12[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M12[e]',
#  'M_bilr_M12[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M14[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M14[e]',
#  'M_bilr_M14[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M15[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M15[e]',
#  'M_bilr_M15[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M16[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M16[e]',
#  'M_bilr_M16[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M7[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bilr_M7[e]',
#  'M_bilr_M7[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_biomass[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_brv[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_brv[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_brv[e]',
#  'M_brv[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bsn[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bsn[e]',
#  'M_bsn[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bsn_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bsn_glc[e]',
#  'M_bsn_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_btamp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_btcoa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_btn[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_btn_co2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_but2eACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_butACP[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_but[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_butpi[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bvu[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bvu[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bvu[e]',
#  'M_bvu[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bz[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bz[e]',
#  'M_bz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bz_glc[e]',
#  'M_bz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bzam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bzam[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_bzam[e]',
#  'M_bzam[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ca2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ca2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ca2[e]',
#  'M_ca2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_caribup_s[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_caribup_s[e]',
#  'M_caribup_s[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_caribupglu_S[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_caribupglu_S[e]',
#  'M_caribupglu_S[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbasp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbi[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbl1[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbl1[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbl1[e]',
#  'M_cbl1[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbl2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbl2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbl2[e]',
#  'M_cbl2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbz[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbz[e]',
#  'M_cbz[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbz_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cbz_glc[e]',
#  'M_cbz_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd2[e]',
#  'M_cd2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd6168[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd6168[e]',
#  'M_cd6168[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd6168_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cd6168_glc[e]',
#  'M_cd6168_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdaihpdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdaipdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdddecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdhdec9eg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdhdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdihdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdihpdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdipdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpditdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdodec11eg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdodecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdtdec7eg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpdtdecg[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpglc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cdpglyc[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cellb[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cgly[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cgly[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cgly[e]',
#  'M_cgly[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chlphncl[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chlphncl[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chlphncl[e]',
#  'M_chlphncl[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chlphncl_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chlphncl_glc[e]',
#  'M_chlphncl_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chol[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cholate[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cholate[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cholate[e]',
#  'M_cholate[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chols[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chor[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_chtbs[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cit[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cit[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cit[e]',
#  'M_cit[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_citr_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ckdo[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cl[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cl[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cl[e]',
#  'M_cl[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb[e]',
#  'M_clcxb[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb_c[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb_c[e]',
#  'M_clcxb_c[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb_c_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb_c_glc[e]',
#  'M_clcxb_c_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clcxb_glc[e]',
#  'M_clcxb_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clobi_c[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clobi_c[e]',
#  'M_clobi_c[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clobi_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clobi_glc[e]',
#  'M_clobi_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpn140[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpn160[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpn180[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpnai15[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpnai17[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpni14[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpni15[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpni16[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_clpni17[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cmp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_co1dam[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_co2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_co2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_co2[e]',
#  'M_co2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_co[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_coa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cobalt2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cobalt2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cobalt2[e]',
#  'M_cobalt2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_colipa[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core2[e]',
#  'M_core2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core3[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core3[e]',
#  'M_core3[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core4[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core4[e]',
#  'M_core4[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core5[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core5[e]',
#  'M_core5[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core6[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core6[e]',
#  'M_core6[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core7[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core7[e]',
#  'M_core7[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core8[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_core8[e]',
#  'M_core8[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cro4[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cro4[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cro4[e]',
#  'M_cro4[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_crvsm1[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_crvsm1[e]',
#  'M_crvsm1[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_crvsm23[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_crvsm23[e]',
#  'M_crvsm23[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_a[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_a[e]',
#  'M_cspg_a[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_a_degr[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_a_degr[e]',
#  'M_cspg_a_degr[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_ab_rest[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_ab_rest[e]',
#  'M_cspg_ab_rest[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_b[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_b[e]',
#  'M_cspg_b[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_b_degr[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_b_degr[e]',
#  'M_cspg_b_degr[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_c[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_c[e]',
#  'M_cspg_c[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_c_degr[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_c_degr[e]',
#  'M_cspg_c_degr[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_c_rest[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cspg_c_rest[e]',
#  'M_cspg_c_rest[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ctbt[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ctbt[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ctbt[e]',
#  'M_ctbt[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cthzp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_ctp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cu2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cu2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cu2[e]',
#  'M_cu2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cvm1gluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cvm1gluc[e]',
#  'M_cvm1gluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cvm23gluc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cvm23gluc[e]',
#  'M_cvm23gluc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cys_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cyst_L[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cytd[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cytd[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_cytd[e]',
#  'M_cytd[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_czp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_czp[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_czp[e]',
#  'M_czp[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_daa[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_daa[e]',
#  'M_daa[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_daa_glc[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_daa_glc[e]',
#  'M_daa_glc[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_dad_2[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_dad_2[e]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_dad_2[e]',
#  'M_dad_2[p]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_dad_5[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_dadp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_damp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_dann[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_datp[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  'M_db4p[c]_M_Bacteroides_thetaiotaomicron_VPI_5482',
#  ...]

# %%
constraints = {'R_EX_fe2[e]':(-0.00007,0),'R_EX_pheme[e]':(-0.0000001,0),'R_prot_pool_exchange_M_Bacteroides_thetaiotaomicron_VPI_5482':(0,1),'R_prot_pool_exchange_M_Escherichia_coli_ED1a':(0,1)}
solution1 = sim1.simulate(constraints=constraints)

print(solution1)
# Out:
# objective: 3.229452607782981e-05
# Status: OPTIMAL
# Method:SimulationMethod.FBA

# %%
print(solution1.find(['R_EX_fe2','R_EX_pheme','R_DM_pheme']))
# Out:
#                                                        Flux rate
# Reaction ID
# R_EX_fe2(e)_M_Bacteroides_thetaiotaomicron_VPI_... -3.000000e-07
# R_EX_pheme(e)_REV_M_Bacteroides_thetaiotaomicro... -1.000000e-07
# R_EX_fe2[e]                                        -3.000000e-07
# R_EX_pheme[e]                                      -1.000000e-07

# %%
print(solution1.find(['R_prot_pool']))
# Out:
#                                                     Flux rate
# Reaction ID
# R_prot_pool_exchange_M_Bacteroides_thetaiotaomi...        1.0
# R_prot_pool_exchange_M_Escherichia_coli_ED1a              1.0

# %%
solution1.find('R_biomass')
# Out:
#                                                    Flux rate
# Reaction ID
# R_biomass_M_Bacteroides_thetaiotaomicron_VPI_5482   0.000032
# R_biomass_M_Escherichia_coli_ED1a                   0.000016

# %%
solution1.get_constraints()
# Out:
# OrderedDict([('R_EX_fe2[e]', (-7e-05, 0)),
#              ('R_EX_pheme[e]', (-1e-07, 0)),
#              ('R_prot_pool_exchange_M_Bacteroides_thetaiotaomicron_VPI_5482',
#               (0, 1)),
#              ('R_prot_pool_exchange_M_Escherichia_coli_ED1a', (0, 1))])

# %% [markdown]
# ## SteadyCom

# %%
from mewpy.cobra.com import SteadyCom

constraints = {'R_EX_fe2[e]':(-0.00007,0),'R_EX_pheme[e]':(-0.0000001,0),'R_prot_pool_exchange_M_Bacteroides_thetaiotaomicron_VPI_5482':(0,0.8),'R_prot_pool_exchange_M_Escherichia_coli_ED1a':(0,0.095)}
solution1 = SteadyCom(sample1,constraints=constraints)
# Out:
# Set parameter FeasibilityTol to value 1e-09
# Set parameter OptimalityTol to value 1e-09
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 from mewpy.cobra.com import SteadyCom
#       3 constraints = {'R_EX_fe2[e]':(-0.00007,0),'R_EX_pheme[e]':(-0.0000001,0),'R_prot_pool_exchange_M_Bacteroides_thetaiotaomicron_VPI_5482':(0,0.8),'R_prot_pool_exchange_M_Escherichia_coli_ED1a':(0,0.095)}
# ----> 4 solution1 = SteadyCom(sample1,constraints=constraints)
#
# File /usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/mewpy-0.1.31-py3.9.egg/mewpy/cobra/com/steadycom.py:50, in SteadyCom(community, constraints, solver)
#      47 objective = community.biomass
#      48 sol = binary_search(solver, objective, minimize=False, constraints=constraints)
# ---> 50 solution = CommunitySolution(community, sol.values)
#      51 solution.solver = solver
#      52 return solution
#
# File /usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/mewpy-0.1.31-py3.9.egg/mewpy/cobra/com/steadycom.py:218, in CommunitySolution.__init__(self, community, values)
#     216 self.normalized = None
#     217 self._exchange_map = None
# --> 218 self.parse_values()
#
# File /usr/local/Caskroom/miniforge/base/envs/tmcom/lib/python3.9/site-packages/mewpy-0.1.31-py3.9.egg/mewpy/cobra/com/steadycom.py:244, in CommunitySolution.parse_values(self)
#     242 for org_id, organism in self.community.organisms.items():
#     243     growth_i = self.community.organisms_biomass[org_id]
# --> 244     self.abundance[org_id] = self.values[growth_i] / self.growth
#     246 self.exchange = {r_id: self.values[r_id]
#     247                  for r_id in model.get_exchange_reactions()}
#     249 self.internal = {}
#
# ZeroDivisionError: float division by zero

# %%
print(solution1)

# %%
reaction_map = sample1.reaction_map
exchanges = {}

for m_id in sim1.get_external_metabolites():
    if sample1.flavor == 'reframed':
        m_id = m_id.strip('M_')
    for org_id, organism in sample1.organisms.items():
        #org_id = org_id.strip('M_')
        #print(m_id)
        rate = 0
        if m_id not in organism.metabolites:
            #print('no')
            continue
        for r_id in organism.get_metabolite_reactions(m_id):
            #print(r_id)
            if (org_id, r_id) not in reaction_map:
                print(r_id)
                #print('no')
                continue

            flux = solution1.values[reaction_map[(org_id, r_id)]]
            #print(flux)
            if flux != 0:
                coeff = organism.get_reaction(r_id).stoichiometry[m_id]
                rate += coeff*flux

        if rate != 0:
            exchanges[(org_id, m_id)] = rate
print(exchanges)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 reaction_map = sample1.reaction_map
#       2 exchanges = {}
# ----> 4 for m_id in sim1.get_external_metabolites():
#       5     if sample1.flavor == 'reframed':
#       6         m_id = m_id.strip('M_')
#
# NameError: name 'sim1' is not defined

# %%
sample1.reaction_map

# %%
cross_all = []
abstol=1e-6
as_df = True

for m_id in sample1.merged_model.get_external_metabolites():
    if sample1.flavor == 'reframed':
        m_id = m_id.strip('M_')
    r_out = {x: r for (x, m), r in exchanges.items() if m == m_id and r > abstol}
    r_in = {x: -r for (x, m), r in exchanges.items() if m == m_id and -r > abstol}
    if m_id =='ca2[e]':
        print(r_out)
        print(r_in)

    total_in = sum(r_in.values())
    total_out = sum(r_out.values())
    total = max(total_in, total_out)

    if total_in > total_out:
        r_out[None] = total_in - total_out
    if total_out > total_in:
        r_in[None] = total_out - total_in

    cross = [(o1, o2, m_id, r1 * r2 / total) for o1, r1 in r_out.items() for o2, r2 in r_in.items()]
    cross_all.extend(cross)

if as_df:
    from pandas import DataFrame
    cross_all = DataFrame(cross_all, columns=["donor", "receiver", "compound", "rate"])

cross_all

# %%
solution1.compute_exchanges()
# Out:
# {}

# %%
build_escher(fluxes=solution1.internal['M_Escherichia_coli_ED1a'])

# %%
build_escher(fluxes=solution1.internal['M_Bacteroides_thetaiotaomicron_VPI_5482'])

# %%
from mewpy.cobra.com import SteadyComVA
variability = SteadyComVA(sample1, obj_frac=0.2, constraints=M9)

print('Strain\tMin\tMax')
for strain, (lower, upper) in variability.items():
    print(f'{strain}\t{lower:.1%}\t{upper:.1%}')

# %%
from mewpy.cobra.com import SteadyComVA

l_va = np.linspace(0.1,1.0,num=10)

for va in l_va:
    va = round(va, 1)
    variability = SteadyComVA(sample1, obj_frac=va, constraints=M9)
    print(f'Strain\tMin\tMax\tVariability - {va}')
    for strain, (lower, upper) in variability.items():
        print(f'{strain}\t{lower:.1%}\t{upper:.1%}')

# %% [markdown]
# ## SMETANA - Species Metabolic Interaction Analysis
#
# **SMETANA** implements several algorithms to analyse cross-feeding interactions in microbial communities. These have been describe in [Zelezniak et al, PNAS (2015)](https://www.pnas.org/doi/abs/10.1073/pnas.1421834112).

# %%
SCS = sc_score(sample1,environment=M9)

# %%
print(pd.DataFrame.from_dict(SCS).to_string())

# %%
MUS = mu_score(sample1,environment=constraints)

# %%
print(pd.DataFrame.from_dict(MUS).to_string())

# %%
MPS = mp_score(sample1,environment=constraints)

# %%
print(pd.DataFrame.from_dict(MPS).to_string())

# %%
score,MIP = mip_score(sample1)
